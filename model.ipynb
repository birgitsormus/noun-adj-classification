# %% [markdown]
# ### Fetching data from the database

# %%
import psycopg2

# %%
con = psycopg2.connect(user = "postgres",
                       password = "",
                       host = "127.0.0.1",
                       port = "5432",
                       database = "adj_noun_pairs")

try:
    cursor = con.cursor();
except (Exception, psycopg2.Error) as error:
    print("Error in Connection",error)

# %%
try:
    cursor.execute("SELECT * FROM pair_counts_10000 WHERE noun IN (SELECT noun FROM pair_counts_10000 GROUP BY noun HAVING COUNT(*) >= 5)")
    pairs = cursor.fetchall() 
except (Exception, psycopg2.Error) as error:
    con.rollback()
    print("Error while inserting data into the table:", error)

# %%
pairs[0]
# Out:
# ('viimane', 'aasta', 1493)

# %%
len(pairs)
# Out:
# 284340

# %%
adjs = list(set([pair[0] for pair in pairs]))
nouns = list(set([pair[1] for pair in pairs]))

# %%
print(len(nouns), len(adjs))
# Out:
# 10521 20266

# %% [markdown]
# ### Data to dataframe

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(0, index=nouns, columns=adjs)
df.head()
# Out:
#                        produtseeriv  koolitatud  viiesaja-aastane  \
# ümberjagamine                     0           0                 0
# palm                              0           0                 0
# rahatrahv                         0           0                 0
# tavakool                          0           0                 0
# post-RISC-arhitektuur             0           0                 0
#
#                        vikerkaarevärviline  novembriöine  maoistlik  \
# ümberjagamine                            0             0          0
# palm                                     0             0          0
# rahatrahv                                0             0          0
# tavakool                                 0             0          0
# post-RISC-arhitektuur                    0             0          0
#
#                        helesinine  piinarikas  jutukas  keerelnud  ...  \
# ümberjagamine                   0           0        0          0  ...
# palm                            0           0        0          0  ...
# rahatrahv                       0           0        0          0  ...
# tavakool                        0           0        0          0  ...
# post-RISC-arhitektuur           0           0        0          0  ...
#
#                        kondenseeruv  valikuline  kõrvalepandud  spetsiaal  \
# ümberjagamine                     0           0              0          0
# palm                              0           0              0          0
# rahatrahv                         0           0              0          0
# tavakool                          0           0              0          0
# post-RISC-arhitektuur             0           0              0          0
#
#                        tõusiklik-anarhistlik  heterotroofne  ekstaatiline  \
# ümberjagamine                              0              0             0
# palm                                       0              0             0
# rahatrahv                                  0              0             0
# tavakool                                   0              0             0
# post-RISC-arhitektuur                      0              0             0
#
#                        10palliline  sõnalõpuline  kalmusetaoline
# ümberjagamine                    0             0               0
# palm                             0             0               0
# rahatrahv                        0             0               0
# tavakool                         0             0               0
# post-RISC-arhitektuur            0             0               0
#
# [5 rows x 20266 columns]

# %%
for tup in pairs:
    df.loc[tup[1], tup[0]] = tup[2]

# %%
df.head()
# Out:
#                        produtseeriv  koolitatud  viiesaja-aastane  \
# ümberjagamine                     0           0                 0
# palm                              0           0                 0
# rahatrahv                         0           0                 0
# tavakool                          0           0                 0
# post-RISC-arhitektuur             0           0                 0
#
#                        vikerkaarevärviline  novembriöine  maoistlik  \
# ümberjagamine                            0             0          0
# palm                                     0             0          0
# rahatrahv                                0             0          0
# tavakool                                 0             0          0
# post-RISC-arhitektuur                    0             0          0
#
#                        helesinine  piinarikas  jutukas  keerelnud  ...  \
# ümberjagamine                   0           0        0          0  ...
# palm                            0           0        0          0  ...
# rahatrahv                       0           0        0          0  ...
# tavakool                        0           0        0          0  ...
# post-RISC-arhitektuur           0           0        0          0  ...
#
#                        kondenseeruv  valikuline  kõrvalepandud  spetsiaal  \
# ümberjagamine                     0           0              0          0
# palm                              0           0              0          0
# rahatrahv                         0           0              0          0
# tavakool                          0           0              0          0
# post-RISC-arhitektuur             0           0              0          0
#
#                        tõusiklik-anarhistlik  heterotroofne  ekstaatiline  \
# ümberjagamine                              0              0             0
# palm                                       0              0             0
# rahatrahv                                  0              0             0
# tavakool                                   0              0             0
# post-RISC-arhitektuur                      0              0             0
#
#                        10palliline  sõnalõpuline  kalmusetaoline
# ümberjagamine                    0             0               0
# palm                             0             0               0
# rahatrahv                        0             0               0
# tavakool                         0             0               0
# post-RISC-arhitektuur            0             0               0
#
# [5 rows x 20266 columns]

# %% [markdown]
# ### Model creation and training

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
lda = LatentDirichletAllocation(n_components=500, random_state=1)
lda.fit_transform(df)
# Out:
# array([[2.22222222e-04, 2.22222222e-04, 2.22222222e-04, ...,
#         2.22222222e-04, 2.22222222e-04, 2.22222222e-04],
#        [1.81818182e-04, 1.81818182e-04, 1.81818182e-04, ...,
#         1.81818182e-04, 1.81818182e-04, 1.81818182e-04],
#        [5.40540541e-05, 5.40540541e-05, 5.40540541e-05, ...,
#         5.40540541e-05, 5.40540541e-05, 5.40540541e-05],
#        ...,
#        [3.33333333e-04, 3.33333333e-04, 3.33333333e-04, ...,
#         3.33333333e-04, 3.33333333e-04, 3.33333333e-04],
#        [3.44827586e-05, 3.44827586e-05, 3.44827586e-05, ...,
#         3.44827586e-05, 3.44827586e-05, 3.44827586e-05],
#        [6.89655172e-05, 6.89655172e-05, 6.89655172e-05, ...,
#         6.89655172e-05, 6.89655172e-05, 6.89655172e-05]])

# %%
topics_test = {}
for i in range(500):
    topics_test[i] = []
    
topic_probs_test = lda.transform(df)
for i, prob in enumerate(topic_probs_test):
    topics_test[np.argmax(prob)].append(df.index[i])

# %%
print([len(topic) for topic in topics_test.values()])
# Out:
# [18, 19, 19, 9, 24, 9, 7, 23, 14, 13, 13, 22, 9, 44, 20, 16, 86, 35, 140, 19, 20, 15, 9, 17, 10, 10, 45, 18, 19, 9, 13, 16, 18, 14, 16, 26, 12, 16, 21, 24, 15, 13, 51, 15, 28, 17, 34, 21, 12, 12, 26, 14, 18, 22, 43, 10, 34, 11, 16, 13, 16, 5, 16, 34, 11, 6, 17, 4, 36, 17, 39, 14, 14, 10, 20, 24, 15, 36, 28, 6, 9, 17, 20, 15, 23, 7, 14, 32, 12, 13, 21, 27, 22, 8, 14, 13, 10, 13, 79, 18, 7, 11, 12, 25, 16, 27, 31, 8, 11, 13, 21, 16, 9, 14, 10, 26, 14, 10, 19, 19, 38, 33, 11, 24, 8, 22, 21, 26, 16, 29, 27, 11, 32, 19, 48, 7, 12, 19, 11, 50, 15, 89, 15, 75, 42, 13, 8, 9, 14, 13, 9, 14, 26, 19, 13, 17, 14, 13, 16, 10, 19, 10, 6, 19, 20, 13, 20, 27, 11, 4, 23, 27, 19, 167, 17, 11, 12, 18, 32, 13, 15, 16, 30, 21, 20, 21, 14, 21, 32, 22, 24, 18, 14, 17, 39, 32, 21, 6, 18, 17, 61, 26, 24, 11, 25, 18, 43, 113, 19, 16, 18, 35, 6, 25, 62, 37, 13, 13, 10, 9, 10, 13, 21, 33, 18, 36, 13, 11, 31, 29, 62, 11, 16, 25, 19, 17, 82, 15, 10, 14, 13, 20, 23, 13, 16, 22, 12, 13, 12, 16, 19, 9, 8, 29, 19, 15, 19, 26, 21, 16, 10, 57, 29, 20, 15, 30, 18, 18, 28, 52, 31, 36, 21, 12, 26, 97, 22, 18, 31, 44, 18, 17, 30, 19, 45, 19, 10, 14, 22, 20, 14, 15, 16, 18, 14, 12, 19, 17, 14, 17, 14, 24, 15, 13, 14, 13, 13, 37, 15, 15, 10, 25, 14, 15, 41, 14, 13, 16, 16, 21, 11, 15, 18, 25, 25, 20, 15, 12, 13, 20, 3, 12, 116, 17, 12, 14, 9, 34, 24, 18, 21, 14, 46, 14, 28, 9, 12, 21, 26, 35, 10, 23, 15, 15, 22, 32, 19, 15, 9, 18, 16, 20, 21, 11, 13, 14, 15, 20, 24, 23, 28, 21, 11, 12, 71, 16, 26, 15, 33, 12, 8, 12, 20, 22, 27, 21, 15, 12, 7, 13, 28, 9, 32, 18, 17, 10, 10, 8, 26, 16, 13, 17, 25, 33, 12, 14, 9, 22, 24, 13, 15, 25, 18, 19, 8, 14, 10, 21, 18, 9, 21, 11, 19, 19, 29, 19, 13, 12, 6, 14, 43, 23, 12, 44, 13, 15, 14, 68, 19, 36, 21, 7, 27, 21, 54, 22, 26, 12, 21, 23, 24, 11, 33, 16, 15, 35, 20, 19, 49, 17, 21, 12, 23, 17, 22, 18, 18, 14, 8, 6, 8, 25, 13, 17, 12, 16, 24, 16, 12, 14, 14, 16, 7, 8, 16, 40, 12, 33, 14, 25, 13, 18, 20, 7, 25, 32, 18, 20, 28, 13]

# %%
for i in range(500):
    if len(topics_test[i]) > 5 and len(topics_test[i]) < 20:
        print(topics_test[i])
        print("---------------------------------")
# Out:
# ['jaapanlane', 'välistuum', 'muutja', 'elukvaliteet', 'konsortsium', 'magma', 'meelemürk', 'viski', 'mälujälg', 'vaik', 'heroiin', 'refleksiivsus', 'liustik', 'ülakiht', 'õppeprotsess', 'ligipääs', 'kahetsus', 'arvutitarkvara']
# ---------------------------------
# ['paavian', 'läbimüük', 'muretsemine', 'raudtee', 'sõiduk', 'prestiiž', 'ausammas', 'lahing', 'koguhulk', 'hoidla', 'infoühiskond', 'pühapäev', 'arsenal', 'tramm', 'sajandialgus', 'äriinimene', 'sümbolipaar', 'kriminaalasi', 'soomusauto']
# ---------------------------------
# ['läige', 'ehedus', 'dokumentaal', 'kinkimine', 'esitus', 'riigikaitse', 'zhürii', 'sissekandmisluba', 'domineerimine', 'noot', 'olulisus', 'tahteavaldus', 'kinnistusamet', 'keskaeg', 'reklaamiandja', 'list', 'deklaratsioon', 'äripäev', 'keskkonnaamet']
# ---------------------------------
# ['tähistaevas', 'organism', 'pensionireform', 'abiline', 'meditsiinipraktika', 'elevant', 'aatom', 'meditsiin', 'välispoliitika']
# ---------------------------------
# ['miin', 'täpsus', 'kõrgus', 'CMOS-tehnoloogia', 'sisu', 'üksikisik', 'jõukatsumine', 'vale', 'ülekandmine']
# ---------------------------------
# ['piiriala', 'reprodutseerimine', 'võrrand', 'tasakaalutus', 'teelõik', 'sundtäitmine', 'juhiluba']
# ---------------------------------
# ['teatrimärk', 'kopeerimine', 'telefonivõrk', 'ristmik', 'muutmälu', 'inimasustus', 'rahatäht', 'rongkäik', 'veelahe', 'õppesisu', 'maardla', 'eeslinn', 'laiuskraad', 'signaaliprotsessor']
# ---------------------------------
# ['õlg', 'pühak', 'romantika', 'võlasuhe', 'võõrvaldaja', 'kasvataja', 'huvitatus', 'järelvalve', 'osakonnajuhataja', 'vabaabielu', 'prognoosija', 'koolnu', 'koordineerimine']
# ---------------------------------
# ['kasutamine', 'kogemine', 'laad', 'pretsedent', 'teadvus', 'gammakiirgus', 'kõrv', 'kiir', 'vanatüdruk', 'ettevalmistamine', 'kärpimine', 'tööjaotus', 'nõudmine']
# ---------------------------------
# ['regulatsioon', 'suurriik', 'leiutamine', 'kõrvutamine', 'teatmeteos', 'margariin', 'kogu', 'kollektsioon', 'massiüritus']
# ---------------------------------
# ['jäljeprotsessor', 'köis', 'rikkur', 'diiler', 'protsessorarhitektuur', 'protsessor', 'operatsioonisüsteem', 'jadapöördus', 'ess', 'mikroarhitektuur', 'kasutus', 'superskalaarprotsessor', 'tööriistakast', 'nullkoht', 'laen', 'koodnimi']
# ---------------------------------
# ['kliendisuhe', 'töömees', 'uuring', 'toimimine', 'ütlus', 'ettepanek', 'mälestussammas', 'allkiri', 'regi', 'juhis', 'osavus', 'kooliskäimine', 'ühik', 'kelk', 'troonipärija', 'mõttemaailm', 'täiendkoolitus', 'eagrupp', 'ehtsus']
# ---------------------------------
# ['haldusakt', 'karakter', 'ootus', 'kasvatustöö', 'allianss', 'inimesekujutus', 'tsivilisatsioon', 'nonsenss', 'apostel', 'paine', 'emantsipatsioon', 'regressioon', 'aastatuhandevahetus', 'egoism', 'ettekuulutus']
# ---------------------------------
# ['õppeasutus', 'reaktsioon', 'laser', 'monstrum', 'loba', 'kaubavedu', 'solist', 'kallak', 'ärritus']
# ---------------------------------
# ['ringlus', 'tagasiside', 'arest', 'omandaja', 'välistamine', 'ringreis', 'nähtus', 'vabaturg', 'transkriptsioon', 'interpretaator', 'augustikuu', 'fraktsioon', 'muutlikkus', 'täpsustus', 'omandamine', 'seletamine', 'mugavus']
# ---------------------------------
# ['võimetus', 'lambakoer', 'omavoli', 'kliimamuutus', 'põld', 'kuumalaine', 'sau', 'korravalvur', 'jõuk', 'E-vitamiin']
# ---------------------------------
# ['kokkumäng', 'kasutaja', 'töö', 'tippsport', 'entsüklopeedia', 'morfoloogiasüsteem', 'pettus', 'tegemine', 'bussiliin', 'jutustamine']
# ---------------------------------
# ['determinism', 'paiknemine', 'konjunktuur', 'distsipliin', 'kaubatee', 'kaust', 'joonis', 'äikesetorm', 'majanduskliima', 'poolus', 'vihahoog', 'stardipositsioon', 'kramp', 'ülevõtmine', 'koordinaat', 'märgend', 'teadmistepagas', 'asend']
# ---------------------------------
# ['valk', 'kood', 'hindaja', 'märkus', 'kaupmees', 'osoonisisaldus', 'avaldus', 'asteroid', 'reis', 'hoidmine', 'pidu', 'seisus', 'tunnistamine', 'tänuavaldus', 'kohver', 'kvaliteet', 'vaatepilt', 'teravus', 'liitsõna']
# ---------------------------------
# ['kuningapere', 'profiil', 'teist', 'märgisüsteem', 'perestroika', 'ühing', 'kujundamine', 'koreograafia', 'järg']
# ---------------------------------
# ['omandireservatsioon', 'kultuuriruum', 'rasvasisaldus', 'kogukond', 'moodul', 'iha', 'põliselanik', 'kombineerumine', 'korraldaja', 'sissekäik', 'tulumaks', 'piim', 'kahjum']
# ---------------------------------
# ['turjakõrgus', 'auhind', 'õigeusk', 'gild', 'sünnipäev', 'liitumine', 'töölisteater', 'kirik', 'videoklipp', 'alusparv', 'esitamine', 'kogudus', 'karistusviis', 'lord', 'klooster', 'roog']
# ---------------------------------
# ['majandusteadus', 'sotsiaal', 'tõrjesüsteem', 'vool', 'kohtuprotsess', 'põhjendatus', 'jadaliides', 'server', 'muster', 'võrguelement', 'arendusmeeskond', 'küsitavus', 'võrguseade', 'sõnavorm', 'koda', 'lähenemine', 'kaubamärk', 'seade']
# ---------------------------------
# ['plokk', 'maakoht', 'kont', 'laud', 'eraldatu', 'traditsioon', 'äriidee', 'kaasabi', 'teler', 'näojoon', 'isa', 'koht', 'realiseerumine', 'nägemine']
# ---------------------------------
# ['silmapilk', 'trend', 'absoluut', 'hõivamine', 'võrdpilt', 'siseviimistlus', 'matt', 'kummitus', 'rentimine', 'suundumus', 'otsingumootor', 'inspiratsioon', 'kogumaksumus', 'säde', 'globaliseerumine', 'ehitis']
# ---------------------------------
# ['kujunemine', 'tegevus', 'suusatamine', 'kontekst', 'regionaalpoliitika', 'klient', 'arvuti', 'turist', 'ametipositsioon', 'õppematerjal', 'määramatus', 'mehed-naine']
# ---------------------------------
# ['kuluartikkel', 'tarbeese', 'suhtlemisviis', 'harjumus', 'leib', 'allutamine', 'trenn', 'rahateenimine', 'olustik', 'mentorlus', 'illusioon', 'ühiskeel', 'tööülesanne', 'passiivsus', 'kahtlustus', 'olme']
# ---------------------------------
# ['orgasm', 'sõnake', 'kõrgkultuur', 'luksus', 'toime', 'kiirustamine', 'uinuti', 'kehakaal', 'kartlikkus', 'vaatevinkel', 'kilogramm', 'ettevaatlikkus', 'kabiin', 'kilo', 'laenamine']
# ---------------------------------
# ['häving', 'kaktus', 'lõhkemine', 'nurk', 'komplikatsioon', 'östrogeen', 'raadiosignaal', 'tunnusjoon', 'aastaarv', 'esikolmik', 'raadio', 'süvis', 'korvpall']
# ---------------------------------
# ['ekspertiis', 'võitlus', 'enesetapp', 'tulemuslikkus', 'läbivaatus', 'action', 'peakorter', 'pidur', 'valguskaabel', 'haridustee', 'pallur', 'tunnel', 'kaader', 'mamma', 'kemplemine']
# ---------------------------------
# ['ümberjaotamine', 'lukk', 'omistamine', 'press', 'andmekaitse', 'tutvustus', 'fakt', 'turuplats', 'sissetung', 'metroojaam', 'kõrvaltegelane', 'heller', 'vahepala', 'naaberrahvas', 'pump', 'kunstikriitik', 'tõelisus']
# ---------------------------------
# ['traat', 'numbrituba', 'paatos', 'kallaletung', 'puumaja', 'maamaja', 'reid', 'hari', 'matemaatikaolümpiaad', 'võõrastemaja', 'kivimaja', 'hütt']
# ---------------------------------
# ['keravälk', 'poolehoid', 'aruandlus', 'tuba', 'maht', 'projekteerimine', 'kala', 'tendents', 'kehakeel', 'omandireform', 'sool', 'tuur']
# ---------------------------------
# ['objektiiv', 'rööptöötlus', 'kosmoseteleskoop', 'kandidaat', 'ideeversioon', 'planeering', 'laulatus', 'valm', 'keelamine', 'hall', 'teleskoop', 'vastavus', 'rünnak', 'söögikoht']
# ---------------------------------
# ['vistrik', 'mutatsioon', 'lips', 'fragment', 'protest', 'infoleke', 'vahesein', 'kokkusattumine', 'möödakäija', 'inimorganism', 'tähtkuju', 'näpunäide', 'mööduja', 'leidja', 'selektsioon', 'staar', 'broshüür', 'lumepall']
# ---------------------------------
# ['õigusnorm', 'kadalipp', 'jälitustegevus', 'metsaraie', 'kirjatäht', 'tulirelv', 'vastutustunne', 'meteoriit', 'raie', 'valikuvabadus']
# ---------------------------------
# ['erak', 'harrastamine', 'kajastamine', 'lämmastik', 'kasutajaskond', 'seksuaalteema', 'kodutöö', 'kaja', 'optimist', 'kaitsja', 'levik']
# ---------------------------------
# ['sõitmine', 'iseloomustamine', 'firmamärk', 'lisateave', 'aut', 'kapsel', 'sõiduriist', 'makrotasand', 'mahtuniversaal', 'alumiinium', 'ametiauto', 'kasulikkus', 'lünk', 'etalon', 'päikesesüsteem', 'mõõt']
# ---------------------------------
# ['abielu', 'arengujärk', 'tagamine', 'arvutitehnika', 'mõtlemine', 'areng', 'elatis', 'konflikt', 'peo', 'vestlus', 'sõidustiil', 'mäng', 'liit']
# ---------------------------------
# ['patriarhaat', 'võõrandumine', 'sisseseadmine', 'põhitoonikontuur', 'väävelhape', 'heelium', 'haarang', 'lisand', 'veemass', 'otstarve', 'pastor', 'süüdimatus', 'modell', 'põhisõna', 'pidurdus', 'luuletaja']
# ---------------------------------
# ['ristumine', 'metssiga', 'fraas', 'rohkus', 'ühtekuuluvus', 'jätkumine', 'kihutaja', 'delfiin', 'loodus', 'agressor', 'mikroorganism', 'aru', 'staadium', 'tüvirakk', 'ruutmeeter', 'maastik']
# ---------------------------------
# ['vaste', 'fond', 'viik', 'substraat', 'jõulumaa', 'eetikakoodeks', 'teguviis', 'riietus', 'kassett', 'advokaadibüroo', 'ensüüm']
# ---------------------------------
# ['reetur', 'serv', 'slaid', 'pime', 'äärejoon', 'teeserv']
# ---------------------------------
# ['argumendistruktuur', 'elamus', 'väljendusviis', 'foon', 'üldpilt', 'veebirakendus', 'väljumine', 'tegevussubjekt', 'korrigeerimine', 'tegutsemine', 'äärmusrühmitus', 'tseremoonia', 'tugiverb', 'esikomponent', 'sõlm', 'integreerimine', 'noomen']
# ---------------------------------
# ['tulemus', 'mägi', 'sõjapidamine', 'väliskapital', 'amatsoon', 'õpitulemus', 'des', 'segamine', 'alusmaterjal', 'audiitor', 'abort', 'mäeahelik', 'diskursus', 'iirlane', 'iva', 'laht', 'sõnamäng']
# ---------------------------------
# ['vigur', 'aines', 'eksperiment', 'ilu', 'mander', 'toimetus', 'perering', 'võidusõit', 'nuputamine', 'allee', 'staadion', 'miljöö', 'mängulaad', 'majapidamine']
# ---------------------------------
# ['juurdekasv', 'üldharidus', 'tehisintellekt', 'loobumine', 'haavatavus', 'teostus', 'motivaator', 'teraapia', 'ülekoormatus', 'produktsioon', 'soe', 'muie', 'lepe', 'päevakord']
# ---------------------------------
# ['eurointegratsioon', 'küttesüsteem', 'punaarmee', 'koostoime', 'GSM-võrk', 'sigimine', 'valge', 'strateegiamäng', 'linlane', 'lõppkokkuvõte']
# ---------------------------------
# ['kutse', 'ebaküpsus', 'tagajärg', 'optsioon', 'asjatundja', 'elukutse', 'liitrine', 'vektor', 'sissekukkumine', 'mootor', 'vabanemine', 'norm', 'põrsas', 'keeristorm', 'konstrueerimine']
# ---------------------------------
# ['igatsus', 'toiming', 'reklaamileping', 'eneseteostus', 'ümberpaiknemine', 'meremees']
# ---------------------------------
# ['võsa', 'võte', 'nomenklatuur', 'tava', 'ühtekuuluvustunne', 'tualett', 'suhtlemine', 'elavdamine', 'inimelu']
# ---------------------------------
# ['äss', 'valgusdiood', 'norskamine', 'kirjaviis', 'linnaosa', 'flopiseade', 'nari', 'osalause', 'seisak', 'antiosake', 'hääl', 'video', 'issand', 'riid', 'surfaja', 'karjatus', 'hüüe']
# ---------------------------------
# ['kommenteerimine', 'jäähoki', 'ajakirjandus', 'läbilõige', 'süüme', 'farss', 'E-pomm', 'tagasilükkamine', 'kvaliteedinõue', 'allveelaev', 'korv', 'sööja', 'taies', 'juhtum', 'piibel']
# ---------------------------------
# ['suge', 'sissejuhatus', 'impeerium', 'boks', 'aktsent', 'arenguriik', 'varjund']
# ---------------------------------
# ['aura', 'alatoon', 'kuma', 'kingitus', 'merevaik', 'armastuslugu', 'bassein', 'liberalism', 'rool', 'kuurort', 'unikaalsus', 'tunne', 'udu', 'kitsh']
# ---------------------------------
# ['küüs', 'seik', 'tööstiil', 'visadus', 'faktor', 'mälestusmärk', 'viga', 'narkomaania', 'läbimine', 'tohter', 'vahevara', 'noorsand']
# ---------------------------------
# ['koolisotsiaaltöö', 'käitumisjuhis', 'militarist', 'näitlemine', 'abielupaar', 'jälitaja', 'fenomen', 'hiir', 'päästja', 'rõhuasetus', 'teleshow', 'ühisosa', 'peldik']
# ---------------------------------
# ['atmosfäär', 'põhiolemus', 'liikumissuund', 'toru', 'kuumvahetusmoodul', 'üksus', 'diviis', 'seostamine']
# ---------------------------------
# ['vaheaeg', 'vaatenurk', 'alateema', 'igikelts', 'juhtimisviis', 'postkast', 'kiviaed', 'personifitseerimine', 'toomine', 'ümberkujundamine', 'keskkond', 'infarkt', 'pink', 'oblast']
# ---------------------------------
# ['kummardus', 'tööviis', 'tööhõive', 'õigusloome', 'töövorm', 'morfoloogia', 'düsfunktsioon', 'tegevusobjekt', 'rahuldus', 'teener', 'deklareerimine', 'hääbumine', 'rannik']
# ---------------------------------
# ['samm', 'lahkumine', 'tükeldus', 'peatus', 'ebamäärasus', 'sõnastik', 'isend', 'ametiühing', 'kindlustus', 'tööpuudus']
# ---------------------------------
# ['lisaaeg', 'müügikäive', 'hilinemine', 'iseseisvusaeg', 'purustusjõud', 'kaksik', 'omaja', 'hapnik', 'palgakasv', 'subintervall', 'eemalolek', 'veeuputus', 'ülalpidamine']
# ---------------------------------
# ['koostöö', 'organisatsioon', 'ajaleht', 'diagnostika', 'pori', 'keskaste', 'kõnealustustasu', 'õpetamine', 'riigitelevisioon', 'töörühm', 'initsiatiiv', 'tihendamine', 'kõne', 'atribuutika', 'välgulöök', 'mäss', 'mõõtmistulemus', 'konverents']
# ---------------------------------
# ['tööjaam', 'pärilikkus', 'kolledzh', 'ohutunne', 'formeering', 'määrsõna', 'grupeering']
# ---------------------------------
# ['põletik', 'harjutus', 'kukeseen', 'virtuaalmeeskond', 'tselluloositehas', 'väetis', 'kitsarinnalisus', 'infektsioon', 'kaardistamine', 'erialakultuur', 'juhtimisteooria']
# ---------------------------------
# ['hotell', 'tank', 'seiklus', 'lift', 'katedraal', 'kask', 'paat', 'org', 'parkla', 'hind', 'e-ülikool', 'müügihind']
# ---------------------------------
# ['sõjamasin', 'energeetik', 'majanduskasv', 'kolmjalg', 'konvergents', 'multimeedia', 'korrastamine', 'struktuurifond', 'montaazh', 'kujutis', 'tempo', 'sportlane', 'eluhoiak', 'kaitseväelane', 'valimiskünnis', 'keeleteadlane']
# ---------------------------------
# ['isiksus', 'rahulolematus', 'koolisotsiaaltöötaja', 'kaaslane', 'pühendumine', 'dialoogsüsteem', 'mainstream', 'vastumeelsus']
# ---------------------------------
# ['kujunduselement', 'suits', 'meedia', 'hooldaja', 'elukindlustus', 'maakaart', 'saatejuht', 'suitsiid', 'õpik', 'sotsiaaltoetus', 'kaigas']
# ---------------------------------
# ['siirdekäsk', 'jää', 'biorütm', 'kuur', 'nauding', 'jutustus', 'leksikon', 'haljasala', 'väikelinn', 'fiktsioon', 'prints', 'asjaajamine', 'süsihappegaas']
# ---------------------------------
# ['algaja', 'kera', 'hingamistee', 'pliiats', 'poolkera', 'daam', 'eshelon', 'võra', 'korrus', 'veresoon', 'sessioon', 'disainer', 'ristkülik', 'graaf', 'äär', 'tekk']
# ---------------------------------
# ['suguhaigus', 'tablett', 'iseseisvus', 'harimine', 'naisametnik', 'piiga', 'maavara', 'medal', 'suhkur']
# ---------------------------------
# ['sardsüsteem', 'koostisosa', 'maandamine', 'tööluba', 'kulu', 'arendamine', 'aspekt', 'põhiharidus', 'arvestus', 'katmine', 'kaasruum', 'saavutamine', 'jehoovatunnistaja', 'noormees']
# ---------------------------------
# ['sülearvuti', 'lend', 'menüü', 'valik', 'ekraan', 'ühtsus', 'erastamine', 'pagasiruum', 'juhe', 'uudsus']
# ---------------------------------
# ['kompass', 'lõuna-aafriklane', 'programmimälu', 'bakter', 'lülitus', 'küüditaja', 'sügisõhtu', 'detailplaneering', 'rauk', 'põletamine', 'duell', 'minimalism', 'üleminekuperiood', 'loodusõnnetus']
# ---------------------------------
# ['suitsetamine', 'isevalitseja', 'paljusus', 'hoiak', 'vabadus', 'shampoon', 'kõrvutus', 'tundemärk', 'jogurt', 'erapooletus']
# ---------------------------------
# ['produktiivsus', 'uuestisünd', 'esirind', 'veetlus', 'kapatsiteet', 'pomm', 'kurnatus', 'mandumine', 'alaareng', 'jõuvaru', 'väsimus', 'geograafia', 'juuksekarv', 'ettevõtja', 'vastupidavus', 'turve', 'turuväärtus', 'taastumine', 'tervis']
# ---------------------------------
# ['tegematajätmine', 'jätkuvus', 'üleminek', 'sõrmus', 'oletus', 'ladustamine', 'edenemine', 'joon', 'graafika', 'paarike', 'oja', 'jäätmed', 'kloor', 'amnestia', 'sündroom', 'krokodill', 'pealuu', 'parasiit', 'beebi']
# ---------------------------------
# ['sari', 'tuum', 'läbisurumine', 'tase', 'loosung', 'ülistamine', 'ilm', 'õhukiht', 'kiht', 'kaup', 'relvastus']
# ---------------------------------
# ['argielu', 'ootamine', 'välisraha', 'loodusjõud', 'pinnakiht', 'lahinguväli', 'vastamine', 'eestvedaja']
# ---------------------------------
# ['hinnavahe', 'korrektsioon', 'põhinimi', 'elusündmus', 'murre', 'finants', 'leevendus', 'väeosa', 'kõikumine', 'eelarvekärbe', 'vähesus', 'maarahvas', 'ellujäämine', 'spekulant', 'hüüatus', 'barjäär']
# ---------------------------------
# ['pamp', 'olevus', 'kosmonaut', 'kaanekujundus', 'päkapikk', 'tegelaskond', 'jaanimardikas', 'vintpüss', 'fotograaf', 'sihik', 'mini']
# ---------------------------------
# ['utoopia', 'kujutus', 'selekteerimine', 'metafoor', 'žanrisüsteem', 'vahetamine', 'keha', 'fikseerimine', 'organiseeritus', 'katseisik', 'lause', 'asetus', 'struktuur', 'kõrgharidusinstitutsioon', 'programse', 'representatsioon', 'moondekivim', 'standardkeel', 'serblane']
# ---------------------------------
# ['kommunikatsiooniakt', 'väliskuju', 'domeeninimi', 'loodusnähtus', 'paekivi', 'arvelevõtmine', 'sünnitamine']
# ---------------------------------
# ['eriala', 'tervik', 'parandamine', 'operatsioon', 'ilmastikutingimused', 'olukord', 'juhtumus', 'majandusolukord', 'tingimus', 'müra', 'ilmastikuolu', 'situatsioon']
# ---------------------------------
# ['vahendus', 'vihavaen', 'murdmine', 'raamatuke', 'pidamine', 'toim', 'brauser', 'reageering', 'ajaperiood', 'lõhn', 'püüdlus', 'õmbleja', 'komitatiiv', 'pinge', 'periood', 'orientatsioon', 'ainevaldkond', 'seksuaalkäitumine', 'partner']
# ---------------------------------
# ['lagunemine', 'kilomeeter', 'edasilükkamine', 'moodustumine', 'karu', 'miil', 'maakoor', 'vahevöö', 'dialoog', 'kultuurisuhe', 'laam']
# ---------------------------------
# ['viljatus', 'sootunnus', 'tähesüsteem', 'riskigrupp', 'basalt', 'uss', 'soojusenergia', 'kiibikomplekt', 'aerosool', 'lemmikpaik', 'eelarveauk', 'lämmastikuühend', 'ümberstruktureerumine', 'tuhk', 'maius']
# ---------------------------------
# ['käendus', 'süüdistatav', 'kohtualune', 'ekspertarvamus', 'isik', 'väljaandja', 'maksekorraldus', 'referent', 'aegumine', 'valu', 'sekretär', 'toimetaja', 'verbivorm', 'ümberkäimine', 'entiteet']
# ---------------------------------
# ['kolesterool', 'väävel', 'veeaur', 'teleesinemine', 'esitusviis', 'osoon', 'jalakäija', 'kvant', 'kosumine', 'footon', 'pisik', 'salakaup', 'iseloomustus']
# ---------------------------------
# ['raamatukogu', 'ruum', 'vaimustus', 'huvi', 'animatsioon', 'väljaõpe', 'võitja', 'tsenter']
# ---------------------------------
# ['roll', 'väärtus', 'moment', 'looduskeskkond', 'komponent', 'tänapäev', 'kaamera', 'materjal', 'rakendusvaldkond']
# ---------------------------------
# ['pürgimine', 'häiritus', 'telefoniraamat', 'farm', 'selgroog', 'ballaad', 'saaga', 'mersu', 'kõrvalepõige', 'tagaajamine', 'keeletehnoloogia', 'rüütel', 'lohutus', 'tiiger']
# ---------------------------------
# ['kvantiteet', 'korraldus', 'tugisüsteem', 'moodustusviis', 'arutamine', 'sissevaade', 'populism', 'teenustepakett', 'galerii', 'rahvusriik', 'hoid', 'parkimine', 'asfalt']
# ---------------------------------
# ['nõrgenemine', 'koosviibimine', 'rahvakultuur', 'perioodilisus', 'ujumine', 'lõõgastumine', 'administraator', 'umbusk', 'halvakspanu']
# ---------------------------------
# ['meri', 'stratosfäär', 'neid', 'infomahutavus', 'süvend', 'pärija', 'säte', 'pilv', 'läbirääkimine', 'mälukiip', 'elektriauto', 'anne', 'lavastamine', 'kloonimine']
# ---------------------------------
# ['seksuaalelu', 'küpsemine', 'ekspluateerimine', 'kuritarvitamine', 'kujutelm', 'erutus', 'vastassugupool', 'stimulatsioon', 'omanikukinnisvõlg', 'pesakond', 'ahistamine', 'aku', 'setu', 'kunstiteos', 'võlu', 'konsultatsioon', 'turismiobjekt', 'kõrvalekalle', 'kestvus']
# ---------------------------------
# ['sündmus', 'algus', 'salk', 'planeet', 'toimumine', 'etendus', 'kunstimaailm', 'eeter', 'MK-etapp', 'mängumaa', 'mõis', 'suurpank', 'beibe']
# ---------------------------------
# ['kurk', 'tuumakatsetus', 'maasikas', 'trass', 'palestiinlane', 'maakodu', 'kadumine', 'püüe', 'toiduaine', 'itaallane', 'seen', 'linnasüda', 'külaelu', 'kalme', 'kaubaartikkel', 'käeliigutus', 'andmepakett']
# ---------------------------------
# ['uurimissuund', 'väikebuss', 'taskuraha', 'vaevatasu', 'käru', 'bandiit', 'sissetulek', 'välikomandör', 'tshetsheen', 'suhtlusvahend', 'rahahulk', 'protsent', 'viivitus', 'merendus']
# ---------------------------------
# ['konservatiivsus', 'omapära', 'spinn', 'sammal', 'kuldkett', 'astenosfäär', 'polaarlaius', 'karjerist', 'rauduks', 'antenn', 'armukadedus', 'invariant', 'köide']
# ---------------------------------
# ['mulje', 'meister', 'õpetaja', 'enesemääratlus', 'antiik', 'kiirgusväli', 'lööklaine', 'elektromagnetkiirgus', 'piirjuht', 'päikesekiirgus', 'lähiminevik', 'elulugu', 'võnkumine', 'vastuvõtt', 'näide', 'kiirgus']
# ---------------------------------
# ['frikatiiv', 'akt', 'sibilant', 'afrikaat', 'klusiil', 'ettekujutus', 'vastuolulisus', 'mantel', 'koolitamine', 'lamp']
# ---------------------------------
# ['kriisiolukord', 'toidukaup', 'maailmaruum', 'publitseerimine', 'lingvistika', 'keelepruuk', 'tsiteerimine', 'pärimus', 'luurerühm', 'liialdamine', 'tollimaks', 'värving', 'prügimägi', 'päikeseenergia', 'perepärimus', 'narratiiv', 'lisaraha', 'pesu', 'lisatasu']
# ---------------------------------
# ['äraütlemine', 'pehmus', 'vastandamine', 'järgnevus', 'vaimukus', 'ämblikuvõrk', 'armastusromaan', 'ülik', 'ilme', 'kohupiim']
# ---------------------------------
# ['identsus', 'küsimustik', 'pakt', 'nõustamine', 'protokoll', 'ühispank']
# ---------------------------------
# ['inimlikkus', 'hoidja', 'IT-teenus', 'city', 'põli', 'teadasaamine', 'majandushuvi', 'emme', 'arvutiklass', 'arestimaja', 'memuaarid', 'doktorant', 'proff', 'loovutamine', 'elamurajoon', 'täheparv', 'lõke', 'botaanikaaed', 'maailmarändur']
# ---------------------------------
# ['viide', 'suuline', 'top', 'keskkool', 'kõvaketas', 'seksuaalvahekord', 'linnapilt', 'allikas', 'ühenduskoht', 'pereelu', 'kohtusüsteem', 'suurteos', 'sidrun']
# ---------------------------------
# ['post-RISC-arhitektuur', 'sein', 'niiskus', 'väiksus', 'vaherahu', 'hajuvus', 'töötlus', 'arvestamine', 'avatus', 'õhuniiskus', 'väljakuulutamine']
# ---------------------------------
# ['amplituud', 'aluspõhi', 'pluus', 'tõrjumine', 'võitluskunst', 'liialdus', 'kellassepp', 'avameelsus', 'veresaun', 'plahvatus', 'trükiallikas', 'lõhkekeha', 'ümberlükkamine', 'propageerija', 'klahv', 'revolver', 'kirurg', 'mõtteviis', 'kirurgia']
# ---------------------------------
# ['protsessorelement', 'figuur', 'bait', 'arvamusliider', 'lähikond', 'reklaamiklipp', 'dokumenteerimine', 'välislugu', 'kajakas', 'rahvasaadik', 'kolmnurk', 'vahe', 'müür', 'hurt', 'side', 'kogusumma', 'tung']
# ---------------------------------
# ['demokratiseerimine', 'psühhiaater', 'skeptitsism', 'demagoogia', 'suguharu', 'algkapital', 'salm', 'häbitunne', 'paaripanek', 'kasutamisoskus', 'lisandgaas']
# ---------------------------------
# ['põhimõiste', 'plika', 'koormamine', 'sidumine', 'käekäik', 'käsuloendur', 'vanaduspension', 'tshempion', 'kirje', 'propagandasõda', 'täpsustamine', 'reorganiseerimine']
# ---------------------------------
# ['näpuviga', 'vanaproua', 'lill', 'leer', 'maapank', 'raudrist', 'lahkheli', 'entusiast', 'rahvavaenlane', 'küsitletu', 'võidu', 'instinkt', 'tald', 'oaas', 'emane', 'paberilipakas', 'poks', 'inspektor']
# ---------------------------------
# ['idioot', 'pangalaen', 'mõtteseos', 'õppelaen', 'seletuskiri', 'kujundus', 'võlglane', 'eraldis', 'pinu', 'majanduskuritegu', 'vereproov', 'kuulmine', 'ümberkorraldamine']
# ---------------------------------
# ['üleskutse', 'püstkoda', 'kustutamine', 'remissioon', 'kadu', 'maffia', 'üksmeel', 'asepeaminister', 'asekantsler', 'lõviosa', 'unustamine', 'poeetika', 'haldusala', 'vrakk', 'tööaeg']
# ---------------------------------
# ['kuuldus', 'sõnaklass', 'kategooria', 'näitaja', 'headus', 'kohtlemine', 'erilisus', 'portree', 'määratletus', 'poolkoks', 'teadusringkond', 'soojus', 'koefitsient', 'grotesk', 'nali', 'embrüo']
# ---------------------------------
# ['kujutlus', 'J-keel', 'platoo', 'koristaja', 'pensionär', 'ekraanipilt', 'naistemees', 'julgeolekunõukogu', 'kvantarvuti', 'hõimurahvas', 'logistika', 'äratundmine', 'liige', 'soomlanna']
# ---------------------------------
# ['süst', 'magistrikraad', 'õping', 'supp', 'välisriik', 'robot', 'süvendamine', 'enesetäiendus', 'advokaat', 'ettevalmistus', 'arhiivitekst', 'navigatsioon', 'rakendustarkvara', 'toetamine', 'arst', 'volinik', 'talent', 'vandeadvokaat']
# ---------------------------------
# ['vaatlusandmed', 'ületamine', 'infosüsteem', 'DK-vahend', 'moodustis', 'konsonant', 'pangahoone', 'kiipkaart', 'sisemus', 'mobiilsidevõrk', 'vedrustus', 'ellipsoidi', 'süsteem', 'haldamine']
# ---------------------------------
# ['silbisuhe', 'ajaskaala', 'põhitoon', 'erakõrgkool', 'värskus', 'sõnavabadus', 'märge', 'teleprogramm', 'rahvavabariik', 'tamm', 'dateerimine', 'kestussuhe', 'uurimisinstituut', 'mall', 'pankrannik', 'televisioon', 'õhtu']
# ---------------------------------
# ['õhk', 'meisterlikkus', 'alkoholisisaldus', 'uudis', 'rajaja', 'nimistu']
# ---------------------------------
# ['rääkimine', 'saun', 'taat', 'pealispind', 'naabrus', 'andmesidevõrk', 'rakendamine', 'lähedus', 'täienduskoolitus', 'arhitektuur', 'põgenik', 'seeme', 'kanalisatsioon', 'potentsiaal', 'liuväli', 'settekivim', 'rahvastikutaaste', 'kontakt']
# ---------------------------------
# ['huul', 'müügitegevus', 'primitiiv', 'ohjamine', 'fail', 'seire', 'praiming', 'infoliiklus', 'edasiliikumine', 'välisilme', 'evolutsioon', 'külastamine', 'jalutuskäik', 'voolavus', 'räsifunktsioon', 'andumus', 'protsess']
# ---------------------------------
# ['kirjeldus', 'tuvastamine', 'käsklus', 'albaanlane', 'antiaine', 'õppekirjandus', 'tööriist', 'õppemaks', 'hetkeolukord', 'andmestruktuur', 'kuuluja']
# ---------------------------------
# ['temperatuurikontrast', 'kandideerija', 'noor', 'eluviis', 'saadikukoht', 'riigivõimuvolitus', 'nõue', 'kahjutasunõue', 'täitmine', 'evolutsiooniteooria', 'reguleering', 'õiguskindlus', 'eesõigus', 'aeglus', 'neeger', 'protestiaktsioon', 'kitsendus', 'koolielu']
# ---------------------------------
# ['alastiolek', 'autorool', 'mootorrattur', 'mõttekäik', 'leopard', 'ööklubi', 'visiir', 'keemia', 'saade', 'kirjutaja', 'võistkond', 'pea', 'pidutseja', 'alkohoolik', 'arenduskeskkond', 'õigustamine', 'kateeder', 'sideliin', 'dotsent']
# ---------------------------------
# ['kaubavahetus', 'geenius', 'publik', 'purk', 'pühavaim', 'pada', 'koolikaaslane', 'külastaja', 'ekspeaminister', 'ahnus', 'doktoriõpe', 'fuajee', 'tolliametnik', 'massimeedia', 'kääbus', 'tööpõld']
# ---------------------------------
# ['tulevikunägemus', 'tühistamine', 'arvamine', 'tulevikustsenaarium', 'läbisõit', 'lepp', 'eeskuju', 'kolin', 'alluvus', 'kapp', 'rahaülekanne', 'vastassugu', 'vastuväide', 'mõistujutt', 'järgimine', 'andja', 'kreen', 'tehing']
# ---------------------------------
# ['kavatsus', 'variatiivsus', 'rahastamine', 'palve', 'tüvi', 'prioon']
# ---------------------------------
# ['avastus', 'kombinatsioon', 'platvorm', 'kirjandus', 'jõutasakaal', 'sõnaliik', 'vestlusring', 'põhitüüp', 'vormistus', 'subjekt', 'mänedžer', 'niit', 'õitseaeg']
# ---------------------------------
# ['kontinent', 'ämber', 'vahendamine', 'hiiglane', 'seltskond', 'sotsialism', 'klassiühiskond', 'rassism', 'hommikupoolik', 'lõppvõistlus', 'päev', 'välimus', 'rangus']
# ---------------------------------
# ['kogumass', 'nimisõna', 'pressimine', 'rööpsus', 'kõrgharidus', 'kujutluspilt', 'päike', 'ülikooliharidus', 'vähk', 'valgustus']
# ---------------------------------
# ['juhendaja', 'ostja', 'klaas', 'aju', 'müstitsism', 'maastur', 'lääs', 'lollus', 'olend']
# ---------------------------------
# ['lesknaine', 'surm', 'esilekutsumine', 'tegelikkus', 'au', 'sünnitus', 'invaliidsus', 'iludus', 'unustus', 'palganumber']
# ---------------------------------
# ['IT-eriala', 'vennaskond', 'tagastamine', 'põhiseadus', 'kõrvalprodukt', 'arendusvahend', 'tarkvarapakett', 'õppekava', 'venestamine', 'loomine', 'nipp', 'omanik', 'maareform']
# ---------------------------------
# ['boikott', 'sepitsus', 'otsustamine', 'haav', 'demonstratsioon', 'kohtuotsus', 'okupeerimine', 'tulem', 'arvutus', 'ärivaldkond', 'ülekuumenemine', 'langetamine', 'alfabeet', 'loe', 'korrutis', 'otsus', 'loode', 'rahulepe']
# ---------------------------------
# ['alamsüsteem', 'professor', 'vahendaja', 'propagandist', 'missioon', 'kokkulepe', 'elektrilaeng', 'moraalinorm', 'transport', 'keskkonnaküsimus', 'vahelüli', 'detail', 'veidrus']
# ---------------------------------
# ['säästmine', 'mask', 'kord', 'tegelane', 'tuumaelektrijaam', 'jah-sõna', 'pöördumine', 'auto', 'kliitor', 'kirss', 'kodanikuportaal']
# ---------------------------------
# ['binokkel', 'soojuskiirgus', 'ida', 'ebavõrdsus', 'võõrdumine', 'sünnikoht', 'diferentseerumine', 'erivajadus', 'valgus', 'pool', 'vald']
# ---------------------------------
# ['vastuvõtja', 'vähemusvalitsus', 'vaatepunkt', 'objekt', 'juurdumine', 'koduarvuti', 'ideaal', 'kokkusaamine', 'dispetsher', 'alune', 'subregioon', 'kasutusvaldus', 'teek', 'organ', 'tõekspidamine', 'ajukoor']
# ---------------------------------
# ['suurettevõtja', 'süsteemsus', 'koonderakond', 'kriips', 'linnavõim', 'bordell', 'eluvõitlus', 'valikuvõimalus', 'muuttüüp', 'vallavalitsus', 'stseen', 'luup', 'hoiu-laenuühistu', 'rahvuspark', 'seriaal', 'nõuanne', 'kratt', 'juubilar', 'keskkoolilõpetaja']
# ---------------------------------
# ['ülesütlemine', 'tagasiandmine', 'hankimine', 'nõu', 'tagatisomandamine', 'väljaandmisnõu', 'klassiruum', 'maapõu', 'riigivõim', 'lahendaja', 'infrastruktuur', 'sissekandmine', 'sissenõudmine', 'täidetus', 'kriteerium', 'meik', 'valdusõigus']
# ---------------------------------
# ['argument', 'liigutus', 'tõmblus', 'valimisvõit', 'tiibetlane', 'veojõud', 'intsident', 'vaataja', 'asutaja', 'sünonüüm', 'sündmustik', 'kohtulahend', 'tõendus', 'töötamine', 'pedofiil']
# ---------------------------------
# ['tunnustus', 'integratsioon', 'oskusteave', 'maailmakeel', 'tädi', 'aare', 'põhjanaaber', 'õhurünnak', 'riigipiir', 'lõpplahendus']
# ---------------------------------
# ['pretensioon', 'klipp', 'mull', 'õigsus', 'kandumine', 'lisamaterjal', 'terviklikkus', 'eelistamine', 'i-mitmus', 'tekst', 'terminoloogia', 'mitmus', 'konspekt', 'käsuplokk']
# ---------------------------------
# ['instituut', 'huumor', 'poolaeg', 'rida', 'seksuaalharidus', 'leegion', 'hüljes', 'varandus', 'maailmameri', 'tikutuli', 'käed-jalg', 'neer', 'igavik']
# ---------------------------------
# ['elustiil', 'vanalinn', 'homoseksualist', 'kurd', 'kude', 'mängimine', 'politseioperatsioon', 'rahvajutt', 'transplantatsioon', 'britt', 'tööturg', 'maailmakirjandus', 'dateering']
# ---------------------------------
# ['langevari', 'ahel', 'kalake', 'retriiver', 'liiga', 'nukleotiid', 'pooldaja', 'suremine', 'keskiga', 'väljaselgitamine', 'ajaloolane', 'kesklinn', 'lähiaasta', 'pärg', 'värv', 'kesktee']
# ---------------------------------
# ['strateegia', 'tavakodanik', 'vindumine', 'lähe', 'juur', 'läbiteinu', 'käibetõde', 'osoonikiht', 'leebus', 'poliitbüroo', 'instrument', 'substantiiv']
# ---------------------------------
# ['seadmine', 'äritehing', 'laine', 'leidmine', 'tõsi', 'kompliment', 'asupaik', 'tagasiastumine', 'möödasõit', 'kaalufunktsioon', 'romantism', 'projekteerimisvahend', 'illustratsioon']
# ---------------------------------
# ['kuulutus', 'tegutseja', 'avaldamine', 'rühmitus', 'prediktor', 'karikatuur', 'abieluleping', 'vaatamisväärsus', 'kohtuasi', 'ambitsioon', 'jääliustik', 'kollisioon']
# ---------------------------------
# ['varieeruvus', 'koolitund', 'balletitantsija', 'omalooming', 'teenindaja', 'folklorist', 'rahapesu', 'islamist', 'presidendikandidaat', 'heterogeensus', 'sisekontroll', 'kurikael', 'kasvukeskkond', 'feminism', 'maksupettus', 'väljamaksmine']
# ---------------------------------
# ['ümberjagamine', 'varjupaik', 'nohu', 'võimalikkus', 'arvutipark', 'koer', 'vaimulik', 'ninasarvik', 'üldpind', 'püüdmine', 'saam', 'kauplus', 'meelevald', 'hord', 'kristlane', 'hundikoer', 'öömaja', 'vajalikkus', 'akvaarium']
# ---------------------------------
# ['närvisüsteem', 'leht', 'kalmistu', 'kartulipõld', 'suurendamine', 'suveöö', 'hobune', 'puhkepaus', 'aroom']
# ---------------------------------
# ['lapsuke', 'oopium', 'pärl', 'turvatase', 'pantija', 'kommunikatsioon', 'asjaõiguskokkulepe', 'kooperatsioon']
# ---------------------------------
# ['lihas', 'araablane', 'õppevahend', 'loogikalülitus', 'pingus', 'käsukonveier', 'jänes', 'tsirkulatsioon', 'takteerimine', 'voolamine', 'konveier', 'aids', 'protsessorlülitus', 'peksmine', 'taktigeneraator', 'uurimis', 'mikro', 'kohtunik', 'kaasavara']
# ---------------------------------
# ['konkurent', 'vatt', 'eraldatus', 'töökogemus', 'käigukast', 'jutuvestja', 'kõnetuvastus', 'katus', 'juura', 'põlemine', 'sümbol', 'teisendamine', 'kanakitkumine', 'the', 'transformeerimine']
# ---------------------------------
# ['spetsialist', 'tuumapomm', 'jääkiht', 'intressitulu', 'räni', 'avaldumisvorm', 'korruptant', 'eraldamine', 'segapuder', 'formaalsus', 'kojutulek', 'sotsiaalministeerium', 'kuju', 'idealist', 'inimsuhe', 'joogivesi', 'evangeelium', 'siirus', 'võltsing']
# ---------------------------------
# ['saast', 'logaritm', 'male', 'süsinik', 'jätkamine', 'lõhustumine', 'jätk', 'saaste', 'isoleeritus', 'kaasnähtus', 'jäätmehoidla', 'asendumine', 'monopol', 'võistlusreis', 'isotoop', 'jalgrattasõit']
# ---------------------------------
# ['ajalõik', 'mõiste', 'paradigma', 'pogromm', 'meeleolu', 'kodusõda', 'patsient', 'väljendamine', 'missioonitunne', 'levi']
# ---------------------------------
# ['prügikast', 'varimajandus', 'mittetulundussektor', 'raskuskiirendus', 'äraelamine', 'elektripirn', 'arengukäik', 'gravitatsiooniväli', 'luu', 'talitlus', 'koolilaps', 'piraatlus', 'individuaalsus', 'korruptsioon', 'elustandard']
# ---------------------------------
# ['väeüksus', 'täiskasvanuiga', 'uurimisrühm', 'koodeks', 'juhend', 'mäluhäire', 'ümarlaud', 'sümfoonia', 'sõnavõtt', 'noorus', 'kooliiga', 'kolonel', 'sisenemine', 'vastuabinõu', 'krahv', 'murdeiga', 'lapseiga', 'džiip']
# ---------------------------------
# ['valmisolek', 'ebaühtlus', 'vähemus', 'IS-strateegia', 'käive', 'üldjuht', 'vihje', 'valimistulemus', 'euroametnik', 'üksikjuht', 'päikesepaiste', 'mängureegel', 'usund', 'rikastumine', 'aastalõpp', 'ungarlane', 'mandaat', 'piirjoon']
# ---------------------------------
# ['põhjus', 'pragu', 'pudel', 'vaenlane', 'tasku', 'vahetus', 'psühhotrauma', 'pärimine', 'tugi', 'lõpmatus', 'maa-ala', 'leiutaja']
# ---------------------------------
# ['kooseksisteerimine', 'rand', 'lihaloom', 'jahiala', 'mererand', 'kannatlikkus', 'männimets', 'vanaduspõlv', 'miiting', 'päikeseloojang', 'tipphetk', 'mikroob', 'duett', 'revolutsioon', 'vanamutt', 'slaavlane', 'viletsus', 'kalliskivi']
# ---------------------------------
# ['määramine', 'geenitehnoloogia', 'õppemeetod', 'maksevahend', 'lask', 'demineerija', 'tehnikaülikool', 'näitlejatar', 'põhiseaduslikkus', 'üldharidussüsteem', 'energiaallikas', 'investeerimisvõimalus', 'järelevalve', 'kohalolu', 'talupoeg', 'päästepaat', 'edastus', 'kasukas']
# ---------------------------------
# ['kultuurikeskus', 'reserveerimine', 'stilisatsioon', 'autobaas', 'kinnisvara', 'kasutusviis', 'ehitusfirma', 'allasutus', 'keelekasutaja', 'suguelu', 'distantseerumine', 'simuleerimine', 'simulatsioon', 'juurdlus', 'küsitlustulemus', 'plaadifirma', 'hooldusfirma']
# ---------------------------------
# ['kattumine', 'süüdistus', 'kiirus', 'piirkond', 'kütt', 'korrelatsioonifunktsioon', 'vajadus', 'laiend', 'kroon', 'varras', 'seeria', 'tähendus', 'kütus', 'järjestus', 'kaabel', 'pinnas', 'vabandus', 'tiitel', 'kirjalikkus']
# ---------------------------------
# ['grammatika', 'tolmupilv', 'rohuneem', 'liiklemine', 'valimiskampaania', 'sõim', 'sõjaväebaas', 'sõit', 'sulgemine', 'raudteejaam', 'kodutee', 'tööstushoone', 'tagasilöök', 'proosa', 'lennuühendus', 'kaevandus', 'probleemistik', 'politseiprefektuur', 'ülevaatamine']
# ---------------------------------
# ['palm', 'lõpetus', 'atlant', 'uurimisteema', 'kirjamees', 'sanatoorium', 'liitmine', 'provintsilinn', 'minevik', 'julgus']
# ---------------------------------
# ['laserkiir', 'spordiklubi', 'pealtkuulamine', 'meessugu', 'kooliõpik', 'külaskäik', 'kanal', 'käsitöö', 'pereisa', 'muulane', 'paavst', 'maksumaksja', 'tasakaalustamine', 'veerg']
# ---------------------------------
# ['kaalutlus', 'suguvõsa', 'vanaisa', 'loodusteadlane', 'rühm', 'leiutis', 'teater', 'tulevik', 'vastutus', 'saamine', 'vanavanem', 'meeskonnaliige', 'kogemus', 'sulitemp']
# ---------------------------------
# ['unistus', 'bikiinid', 'raadiosaade', 'telefon', 'antropoloog', 'IT-süsteem', 'bürokraatia', 'mobiil', 'masin', 'lausung', 'hein', 'tüdruk', 'turg', 'oks', 'silinder']
# ---------------------------------
# ['elukäik', 'õpiteooria', 'informatsioon', 'välkmälulülitus', 'teadus', 'modelleerimine', 'eneseavaldus', 'muutmine', 'info', 'elluviimine', 'taotlus', 'kaltsium', 'hävitaja', 'patent', 'kättesaadavus', 'õigeusukirik']
# ---------------------------------
# ['kosmoselaev', 'kolonn', 'tragöödia', 'muutumine', 'reziim', 'algpõhjus', 'aed', 'kavand', 'lennuk', 'kolleeg', 'autojuht', 'töötlemine', 'koostööprojekt', 'diivan', 'metamorfism', 'vägistamine', 'rahu', 'lihtrahvas']
# ---------------------------------
# ['meeleoluhäire', 'lõhkeaine', 'literaat', 'vihik', 'müügitöö', 'kaas', 'palgatööline', 'igamine', 'aseaine', 'seadusetäht', 'kiilaspäisus', 'plastik', 'laskumine', 'handover']
# ---------------------------------
# ['kiiver', 'eelmärge', 'kordaminek', 'restruktureerimine', 'ehitusplats', 'koletis', 'saabas', 'üür', 'kohandumine', 'teksapüks', 'dialektika', 'intelligents']
# ---------------------------------
# ['tina', 'küpse', 'kass', 'poeg', 'jõmpsikas', 'koolitüdruk', 'sarimõrvar', 'üllataja', 'üleandmine', 'arv', 'kostja', 'üldistus', 'peretütar', 'ametiaeg', 'lastekodu', 'naabritüdruk', 'vaikelu', 'majavalitsus', 'algarv']
# ---------------------------------
# ['valimik', 'koguja', 'masinavärk', 'praam', 'põhivara', 'andmetabel', 'ütlemine', 'tarand', 'prefekt', 'lähtepunkt', 'diasporaa', 'taastamine', 'monograafia', 'videotelefon', 'väljavahetamine', 'saaja', 'parras']
# ---------------------------------
# ['kopsupõletik', 'esiplaan', 'kõneakt', 'kooselu', 'alateadvus', 'kandja', 'madu', 'vahekord', 'koonduslaager', 'teekond', 'maksimum', 'nakkus', 'kang', 'negativism']
# ---------------------------------
# ['pidepunkt', 'nihilist', 'kättemaks', 'agressioon', 'auaste', 'rahvuspoliitika', 'vastuluure', 'ähvardamine', 'komandant', 'hegemoonia', 'läbimurre', 'nihilism', 'pantvang', 'traktaat', 'riigipööre', 'eelarvamus', 'teadlikkus']
# ---------------------------------
# ['koondis', 'süsi', 'uurimus', 'piirimaa', 'vastukaal', 'uurimismaterjal', 'töötajaskond', 'turvalisus', 'kinnitus', 'vabariik', 'lood', 'rahvas', 'nägemus', 'ennetustöö']
# ---------------------------------
# ['amfetamiin', 'läkitus', 'pakett', 'tall', 'meil', 'räim', 'järjekindlus', 'abipalve', 'tuletis', 'administratsioon', 'kreem', 'märgukiri', 'järelepärimine', 'kiri', 'proov']
# ---------------------------------
# ['kasvaja', 'südamehaigus', 'jutt', 'poplugu', 'vastanu', 'imidž', 'rinnavähk', 'hääletaja', 'käsi', 'suhtumine', 'kaitseliit', 'koorik', 'jäse']
# ---------------------------------
# ['lõunasöök', 'kompenseerimine', 'hinnaalandus', 'motell', 'pärand', 'sõjaväeparaad', 'uustulnuk', 'kooliõpetaja', 'jaht', 'eesliin', 'õhtusöök', 'varas', 'peit', 'andmetüüp']
# ---------------------------------
# ['baas', 'tõestus', 'reaalaeg', 'mõju', 'toidulaud', 'maaomanik', 'maksmine', 'kohus', 'klaster', 'kott', 'kangus', 'pahameel', 'formaat']
# ---------------------------------
# ['pürgija', 'tagapõhi', 'rõngas', 'insomnia', 'alanemine', 'unehäire', 'järglane', 'psühhoos', 'arendustegevus', 'kraav', 'omand', 'enurees', 'atakk']
# ---------------------------------
# ['õhustik', 'kett', 'skaala', 'kirjapanek', 'loetav', 'sulane', 'kiidulaul', 'sanktsioon', 'projektsioon', 'kulminatsioon', 'kriminaalkoodeks', 'veekiht', 'pensionipõli', 'tsoon', 'mälestus']
# ---------------------------------
# ['taevalaotus', 'eksemplar', 'tõmblemine', 'terrorismioht', 'lähendamine', 'tõke', 'ebakõla', 'jälgimine', 'peni', 'mesilane', 'otseülekanne', 'viperus', 'sularaha', 'salong', 'genereerimine']
# ---------------------------------
# ['jumal', 'asesõna', 'elufilosoofia', 'tahe', 'süütus', 'biograafia', 'jahedus', 'vanaema', 'eelistus', 'valvur']
# ---------------------------------
# ['jäätis', 'mõtisklus', 'seadusesäte', 'jututekst', 'eduseis', 'rutiin', 'ettekääne', 'pisiasi', 'sisemonoloog', 'abstraktsioon', 'säilimine', 'kuulaja', 'juust', 'veasituatsioon']
# ---------------------------------
# ['tuvastussüsteem', 'tennis', 'ämmaemand', 'psüühikahäire', 'taju', 'rohumaa', 'purjetamine', 'lektor', 'väitekiri', 'rahandussüsteem', 'pronks', 'väljavaade', 'kaevur', 'raev', 'reisikaaslane']
# ---------------------------------
# ['sihtkoht', 'kork', 'fotoaparaat', 'veerpalu', 'haare', 'väikevend', 'tasandik', 'vesi', 'kampaania', 'loom', 'vägi', 'olemine', 'kalju', 'pruukimine']
# ---------------------------------
# ['väljatöötamine', 'fraktaal', 'idee', 'filoloog', 'käsitlusviis', 'ajakiri', 'siirderiik', 'tüüp', 'ime', 'ellusuhtumine', 'uimasti', 'ehitamine', 'versioon']
# ---------------------------------
# ['asjaõigus', 'innovatsioon', 'kahanemine', 'parlament', 'sotsiaalkaitse', 'küngas', 'koostöövorm', 'riigivolikogu', 'meede', 'minister', 'õppimine', 'kariloom', 'president', 'tõestusmaterjal', 'dirigent', 'kokkupuude']
# ---------------------------------
# ['ummik', 'sihtdomeen', 'representatiivsus', 'kauplemine', 'snobism', 'käitumis', 'motoorikahäire', 'foobia', 'menetlus', 'söömishäire', 'massijaotus', 'tundeeluhäire', 'erijoon', 'õpivilumus', 'arenguhäire', 'saasteaine']
# ---------------------------------
# ['test', 'metakeel', 'kobar', 'enamik', 'element', 'liin', 'internet', 'pätt', 'teave', 'jõudmine', 'käsitlemine']
# ---------------------------------
# ['magala', 'relvaäri', 'katalüsaator', 'turvas', 'elektrienergia', 'tehnikaime', 'piiritus', 'parafraas', 'naeratus', 'põllumajandussaadus', 'elekter', 'habemik', 'vahuvein', 'aktsiisimaks', 'immigrant']
# ---------------------------------
# ['ausus', 'imago', 'realist', 'hunt', 'muda', 'luul', 'predikaat', 'memorandum', 'emotsioon', 'klubi', 'unistaja', 'sild', 'pealehakkamine', 'soovunelm', 'fantaasia', 'manifest', 'muna', 'elukorraldus']
# ---------------------------------
# ['kindlakstegemine', 'meditsiiniõde', 'õiguskord', 'ehe', 'vaheltkasu', 'sootsium', 'mõttemäng', 'vastandus', 'kultuurikeskkond', 'väljanägemine', 'veebisait', 'vanapoiss', 'rohelus', 'esituskuju', 'pits']
# ---------------------------------
# ['igavus', 'okupatsioon', 'sõjakool', 'õppekulu', 'üliõpilane', 'ülekandemaht', 'tudeng', 'näitamine', 'tööpäev', 'lapseoode', 'rabelemine', 'leksika']
# ---------------------------------
# ['minek', 'vorm', 'raamistus', 'ajend', 'piir', 'allajäämine', 'rumalus', 'nimekiri', 'kooskäimine', 'ebameeldivus', 'alge', 'märk', 'sektsioon']
# ---------------------------------
# ['vulkaan', 'hüve', 'kaubandus', 'pitsa', 'analoog', 'allusioon', 'muuseum', 'metoodika', 'paralleel', 'lavastus', 'dramaturgia', 'rahvuskultuur']
# ---------------------------------
# ['ravikuur', 'eksport', 'apsakas', 'stabiilsus', 'armuke', 'või', 'õun', 'ravivõimalus', 'üksikasi', 'abi', 'resultaat', 'valetamine', 'sise', 'näit', 'ilmumisaeg', 'tooraine', 'välisabi']
# ---------------------------------
# ['jaanalind', 'kaelkirjak', 'optimeerimine', 'väikerahvas', 'pingviin', 'vutt', 'missivõistlus', 'linnatänav', 'ilutulestik', 'jumalateenistus', 'kristlus', 'bokser']
# ---------------------------------
# ['praktika', 'õpperühm', 'idaeurooplane', 'istumine', 'ärahoidmine', 'vanemahüvitis', 'proua', 'koos-töö', 'uuendus', 'näitleja', 'pale', 'ühinemine', 'reetmine', 'euro']
# ---------------------------------
# ['võrguprotsessor', 'vormel', 'torge', 'urn', 'avaldis', 'bibliograafia', 'riskianalüüs', 'määratlus', 'limusiin']
# ---------------------------------
# ['identifikatsioon', 'kammits', 'vodka', 'silt', 'indeks', 'delegaat', 'ajalooraamat', 'ettevalmistusaeg', 'küünal', 'kutsumine', 'sõjavägi', 'informaatika', 'rahakulutamine', 'näitekirjandus', 'joomine', 'raskus', 'lipik', 'vapustus']
# ---------------------------------
# ['hinnatõus', 'preemia', 'anamnees', 'pealinn', 'sekkumine', 'hinnang', 'politsei', 'kunstnik', 'väljendus', 'e-õpe', 'asukoht', 'toimumisaeg', 'pilt', 'vennas']
# ---------------------------------
# ['tõrge', 'kunstielu', 'kaaskodanik', 'korrutamine', 'mainimine', 'maksukohustus', 'arter', 'keerukus', 'ajaühik', 'arengulugu', 'samba', 'tööstaaž', 'vektorruum', 'pihuarvuti']
# ---------------------------------
# ['monitooring', 'personaalarvuti', 'turvamees', 'eestimaalane', 'miinimum', 'tšetšeen', 'äramärkimine', 'pisar', 'modernsus']
# ---------------------------------
# ['sekund', 'tunnikiirus', 'pandiõigus', 'magistriõpe', 'hallutsinatsioon', 'ebakindlus', 'moratoorium', 'kivim', 'lubjakivi', 'lahutamine', 'kuld', 'töötegija']
# ---------------------------------
# ['kuninganna', 'kuupäev', 'omanikering', 'emaplaat', 'kuum', 'suutmatus', 'kabriolett', 'toor', 'toiteallikas', 'magnetväli']
# ---------------------------------
# ['diskussioon', 'meediakära', 'armusuhe', 'andme', 'seks', 'sagin', 'agenda', 'vanusegrupp', 'õppekoormus', 'käsiraamat', 'vaatlus', 'surmanuhtlus', 'alusdokument', 'süli', 'viisakus']
# ---------------------------------
# ['seos', 'tugevdamine', 'korrelatsioon', 'jagunemine', 'vastandumine', 'esinduskogu', 'selgitamine', 'nõiaring', 'kaugus', 'liiasus', 'efekt', 'erinevus', 'erisus', 'tiib', 'haakumine']
# ---------------------------------
# ['kindlustusfirma', 'veski', 'null', 'kamp', 'võistlemine', 'brünett', 'vestluskaaslane', 'aastapäev', 'telemaastik', 'blondiin', 'nelik', 'peibutis', 'võimekus', 'nõudlikkus', 'kolumnist', 'põhiplaan', 'popmuusika', 'automaatjaam', 'kuldkala']
# ---------------------------------
# ['lisa', 'puusärk', 'doktriin', 'küla', 'satiir', 'kiip', 'hooldekodu', 'ameeriklanna', 'reljeef', 'kong', 'talupidamine', 'pikk', 'naps', 'lootus', 'e-kiri']
# ---------------------------------
# ['piduline', 'partisan', 'helikopter', 'kuluaar', 'merepõhi', 'sokk', 'kanep', 'kuppel', 'aas']
# ---------------------------------
# ['õppetöö', 'suu', 'mälumüür', 'dekoratsioon', 'rikkuja', 'ühistöö', 'puder', 'vaatamine', 'loodusteadus', 'kaotaja', 'paksus', 'käsivars', 'numbrimärk', 'arhiivimaterjal', 'arvutiprogramm', 'hüpoteek', 'osahüpoteek', 'kollaps']
# ---------------------------------
# ['pindala', 'ohtlikkus', 'lahus', 'meloodia', 'fookus', 'lisatähendus', 'sobivus', 'piljardilaud', 'tungimine', 'ühinenu', 'relv', 'toimetulemine', 'leek', 'kabinet', 'neutraliseerimine', 'keemiarelv']
# ---------------------------------
# ['kannapööre', 'kriimustus', 'kooslus', 'haridus', 'kontseptsioon', 'päritolu', 'projektijuhtimine', 'väljapressimine', 'võrdlemine', 'pööre', 'minia']
# ---------------------------------
# ['kalalaev', 'elukeskkond', 'juut', 'pääs', 'tuluke', 'pintsaklipslane', 'jahipüss', 'põlevkivi', 'rahaeraldus', 'kahur', 'püss', 'loeng', 'detonaator']
# ---------------------------------
# ['pähkel', 'alam', 'väljapääs', 'gümnasist', 'seemnerakk', 'vaikimine', 'andmeedastus', 'abikaasa', 'armsam', 'sära', 'madin', 'teenija', 'ports', 'kaebealune']
# ---------------------------------
# ['patt', 'laenukoormus', 'edastamine', 'ennustamine', 'naiskangelane', 'nahavähk', 'peategelane', 'rändur', 'segment', 'elumuutus', 'koolitee', 'nihe', 'fassaad', 'ennustus', 'vihmavari']
# ---------------------------------
# ['tehnoloogia', 'tekkimine', 'morfiin', 'tunnus', 'trikk', 'suund', 'esteetika', 'ülesehitamine', 'teke', 'tegija', 'külg']
# ---------------------------------
# ['seisund', 'õhutamine', 'toitumine', 'ärrituvus', 'reguleerimine', 'kahjustumine', 'alus', 'järjepidevus', 'tasakaaluseisund', 'postulaat', 'sõjavanker', 'hüperaktiivsus']
# ---------------------------------
# ['vangla', 'maaerakond', 'emissioon', 'iidol', 'tollitariif', 'ainevahetus', 'kodulehekülg', 'kehtestamine', 'obligatsioon', 'põgenikelaager', 'hoolealune', 'vabadussõda', 'ümbrik', 'ringkonnakohus', 'alamruum', 'psühhiaatriahaigla']
# ---------------------------------
# ['rändamine', 'teos', 'areaal', 'lennuliin', 'põhjus-tagajärg', 'tõesus', 'esitlemine', 'lõppkontsert', 'lugu', 'ollus', 'väljaanne', 'võre', 'ring', 'vedelik', 'suurlinn']
# ---------------------------------
# ['ressurss', 'dokumendimall', 'unarus', 'puudumine', 'radar', 'motiiv', 'olemasolu', 'teade', 'tees', 'veendumus', 'pealetung', 'maakler']
# ---------------------------------
# ['dekreet', 'kordustrükk', 'suursaadik', 'rahandus', 'ultraviolettkiirgus', 'Bondi-film', 'õis', 'süüdistuskokkuvõte']
# ---------------------------------
# ['rakendumine', 'sündimustase', 'keskkonnatingimus', 'jõhv', 'linnakodanik', 'temperatuur', 'täiendõpe', 'andmekogu', 'sete', 'lõik', 'kurbus', 'turvameede']
# ---------------------------------
# ['kivikuul', 'lõiv', 'rikastamine', 'rahvastikupoliitika', 'heategu', 'teeviit', 'impulss', 'sõnaraamat', 'lappimine', 'õppekoht', 'membraan', 'tähis', 'vältehääldus', 'ainestik', 'keeris']
# ---------------------------------
# ['esperanto', 'riistapuu', 'algfaas', 'katsetamine', 'perspektiiv', 'viisavabadus', 'horisont', 'käitumismudel', 'efektiivsus', 'töösuhe', 'majandusprogramm', 'väljund']
# ---------------------------------
# ['lumi', 'hellitus', 'kuup', 'algebra', 'kalkulatsioon', 'riie', 'muutkond']
# ---------------------------------
# ['saastamine', 'kvantsüsteem', 'parameeter', 'seadeldis', 'varieerumine', 'karakteristik', 'seksuaalsuhe', 'karv', 'nooruk', 'hüüdnimi', 'võhiklikkus', 'omadus', 'töökus']
# ---------------------------------
# ['südametemurdja', 'veri', 'kasutamissagedus', 'kõrvaltoime', 'pürgimus', 'kesk', 'täiendamine', 'väljaütlemine', 'signaal']
# ---------------------------------
# ['sugulaskeel', 'ebaõiglus', 'linnakultuur', 'ilukirjandus', 'sisetunne', 'kultuurilooline', 'novell', 'arengumudel', 'ks-ühend', 'rekonstrueerimine', 'juuksur', 'ülestõusmine', 'paratamatus', 'bänd', 'kõrgtase', 'astroloogia', 'romaan', 'tegevusaeg']
# ---------------------------------
# ['piros', 'põrandapind', 'fort', 'spektriosa', 'laid', 'riigitegelane', 'plastpudel', 'aastakäive', 'jope', 'pass', 'säilitamine', 'kiil', 'toon', 'maalikunstnik', 'kaljusein', 'esitatu', 'põll']
# ---------------------------------
# ['talurahvas', 'sõltumatus', 'omaksvõtt', 'triip', 'lätlane', 'klausel', 'põhiväärtus', 'püsimine', 'kalender', 'suveräänsus']
# ---------------------------------
# ['asustus', 'islamiriik', 'demokraatia', 'koolivaheaeg', 'eesnimi', 'õhtupoolik', 'tagala', 'assamblee', 'käivitamine', 'maneer']
# ---------------------------------
# ['naaberriik', 'mõtteavaldus', 'järjekoht', 'alaliik', 'silmavaade', 'järelmid', 'järeldus', 'muutevorm']
# ---------------------------------
# ['tshintshilja', 'ahv', 'detsentraliseerimine', 'teadusraha', 'talumees', 'majandusharu', 'programm', 'mõõdik', 'usaldus', 'jääk', 'haigekassa', 'põhimõte', 'asutus', 'elektronarvuti', 'tasakaalustamatus', 'surumine']
# ---------------------------------
# ['saastumine', 'äärmus', 'viinamari', 'tõbi', 'terrorist', 'tapp', 'kõnelus', 'hull', 'lehm', 'töönädal', 'tartlane', 'mõisnik', 'dollar']
# ---------------------------------
# ['polünoom', 'telefoninumber', 'raamatupidamine', 'minimeerimine', 'postmodernism', 'idealism', 'kruus', 'õllepudel', 'mõõk', 'koormatis', 'viha', 'pudelikael', 'funktsioon', 'pann', 'ühissõiduk', 'maitseaine', 'perspektiivitunne']
# ---------------------------------
# ['kosmos', 'riisumine', 'alagrupp', 'seaduserikkumine', 'hooletus', 'allilmaliider', 'rütm', 'kuritarvitus', 'äpardus', 'riigipööraja', 'pluss', 'karistamine']
# ---------------------------------
# ['häälteenamus', 'puhastus', 'siseturg', 'käsutuspiirang', 'enamus', 'esiletoomine', 'senat', 'kannatus', 'vaesuspiir', 'lõhe', 'õigustühisus', 'subjektiivsus', 'elutingimus', 'lõpetamine']
# ---------------------------------
# ['uskumus', 'madalrõhkkond', 'käibemaks', 'keskvõim', 'stabiliseerimine', 'rusikas', 'makse', 'vaatleja', 'leedi']
# ---------------------------------
# ['aktsioon', 'CD-plaat', 'ründamine', 'mõttelaad', 'lava', 'lohe', 'tänav', 'gümnaasium', 'vasikas', 'genitiiv', 'jada', 'tervikpilt', 'volitus']
# ---------------------------------
# ['möödalask', 'hädavajadus', 'kontaktandmed', 'jugavool', 'katseklaas', 'e-kaubandus', 'raadium', 'alammuutkond', 'massiiv', 'keeleressurss', 'intervall', 'filminäitleja', 'metaan', 'heide', 'suutlikkus']
# ---------------------------------
# ['autoriõigus', 'andmebaasisüsteem', 'mahv', 'PR-töö', 'tööots', 'telekas', 'hinnasõda', 'linateos', 'täiustus', 'lugemine', 'mõõduvõtmine', 'võidukihutamine', 'rahvahulk', 'atraktsioon', 'faabula', 'orientiir', 'andmebaas', 'naturalist']
# ---------------------------------
# ['dokument', 'lindistus', 'lennuvägi', 'digitaalallkiri', 'väärtpaberitehing', 'andmehõive', 'tõkestamine', 'võhik', 'informant', 'hääletamine', 'pikendus', 'signatuur', 'levitamine', 'jututeema', 'laevatee', 'meediakajastus', 'vormistamine', 'vargus', 'tagaotsitav']
# ---------------------------------
# ['kangas', 'individualism', 'konteiner', 'redigeerimine', 'suhtlus', 'ärakasutamine', 'truudus', 'rahuprotsess']
# ---------------------------------
# ['papagoi', 'mitte-eestlane', 'kodanik', 'maailmapoliitika', 'kooliõpilane', 'hambaarst', 'kogumik', 'kriminaal', 'üldarv', 'majandustegevus', 'sääsk', 'ninaesine', 'kodanikkond', 'kostüüm']
# ---------------------------------
# ['sedel', 'lavastaja', 'hukk', 'võistleja', 'paberitükk', 'reostus', 'ajateenija', 'mõõtmine', 'võimendi', 'ortograafia']
# ---------------------------------
# ['tugipunkt', 'lähenemisviis', 'taktika', 'kompositsioon', 'käimine', 'riigikogu', 'kultuuriministeerium', 'suurusjärk', 'kasu', 'kummardamine', 'avantüür', 'kere', 'koosolek', 'peaminister', 'teavitamine', 'võidumees', 'korpus', 'ministeerium']
# ---------------------------------
# ['rahvus', 'süsivesinik', 'sõjaväelane', 'karjalane', 'savi', 'kuiv', 'tõsiasi', 'väljend', 'loor']
# ---------------------------------
# ['haldussuutlikkus', 'lõppkasutaja', 'vastasmõju', 'vehklemine', 'käegalöömine', 'vastastikmõju', 'võitlemine', 'meeskonnatöö', 'tõmme', 'liikluskeskkond', 'lähtumine']
# ---------------------------------
# ['valmistaja', 'salateenistus', 'otseinvesteering', 'kaitse', 'katkend', 'teataja', 'tarkvaramaailm', 'meeter', 'vastsündinu', 'juuresolek', 'invaliid', 'and', 'muusikapala', 'keelematerjal', 'teadusajakiri', 'süütunne', 'naftakompanii', 'meenutamine', 'loomaaed']
# ---------------------------------
# ['haripunkt', 'kvarts', 'täiskogu', 'maamuna', 'istung', 'kongress', 'peegelpilt', 'teras', 'tai', 'maraton', 'vääriskivi', 'istungjärk', 'amiinohape', 'parlamendivalimine', 'seisukord', 'üldkoosolek', 'lastelugu', 'metall', 'koduloom']
# ---------------------------------
# ['liikluspolitsei', 'kuulsus', 'sisuteenus', 'keskkonnaorganisatsioon', 'vägivaldsus', 'projektitöö', 'arvutivõrk', 'tulistamine', 'telekommunikatsioon', 'abielulahutus', 'kaklus', 'kommunikatsioonikanal', 'meene', 'looduskatastroof', 'tantsupidu', 'lävi', 'töökeskkond', 'andmeside', 'globaalsiin']
# ---------------------------------
# ['ebatäiuslikkus', 'turismireis', 'katoliiklane', 'määre', 'hammas', 'pulmapeo', 'edasiarendus', 'puuvili', 'sigar', 'tera', 'sidevahend', 'lein', 'inimõigus']
# ---------------------------------
# ['oligarh', 'kuulutamine', 'kaunitar', 'käsuaken', 'poseerimine', 'toetaja', 'provokatsioon', 'tervitus', 'perekonnanimi', 'naftafirma', 'friis', 'riigiduuma']
# ---------------------------------
# ['juhtimine', 'öö', 'mänguasi', 'toit', 'perifeeriaseade', 'koostis']
# ---------------------------------
# ['loodusseadus', 'frank', 'digitaalsignatuur', 'horoskoop', 'kasutajaliides', 'isamaa', 'sentimeeter', 'disain', 'suhtekorraldus', 'orgia', 'haarem', 'käsutus', 'riigiaparaat', 'modelleerimiskeel']
# ---------------------------------
# ['savann', 'okasmets', 'süntees', 'murdekeel', 'troposfäär', 'ainsus', 'vallandamine', 'heli', 'muinsuskaitse', 'troopika', 'kliima', 'õhumass']
# ---------------------------------
# ['intressimäär', 'essee', 'autoost', 'kross', 'takt', 'kaastöö', 'aparatuur', 'astronoom', 'põllumajandus', 'keeld', 'peatumine', 'sotsiaaldemokraatia', 'spordiala']
# ---------------------------------
# ['ese', 'psühhopaatia', 'kolju', 'kell', 'loodusvara', 'kanadalane', 'rõhk', 'vend', 'põllumaa', 'laps', 'rehabiliteerimine', 'palgaraha', 'taevakeha', 'maks', 'raha']
# ---------------------------------
# ['piirang', 'raamistik', 'printsiip', 'kalm', 'asümmeetria', 'konfliktsituatsioon', 'häälik', 'raam', 'ülesehitus', 'labor', 'valimissüsteem', 'mõtestamine', 'keeleteadus', 'eripära']
# ---------------------------------
# ['inimloomus', 'staazh', 'bin', 'vaatlemine', 'nuga', 'vutimees', 'olemasolev', 'epiteet', 'eriolukord', 'Mcraad', 'lauluke', 'taldrik', 'tundmus', 'naisuke', 'kontsessioonileping', 'heinamaa', 'pilk', 'professioon', 'politseitöö']
# ---------------------------------
# ['omariiklus', 'skandinaavlane', 'meresõitja', 'teravnemine', 'telomeer', 'egiptlane', 'hindu']
# ---------------------------------
# ['tagamõte', 'usk', 'vanainimene', 'esiema', 'üritus', 'juht', 'tegu', 'liberaalsus', 'autor', 'helind', 'turvamehhanism', 'iseloom']
# ---------------------------------
# ['bilanss', 'heksogeen', 'monument', 'ajurakk', 'loodusressurss', 'tõusmine', 'lõikus', 'tuumaplahvatus', 'ööpäev', 'kirjavahetus', 'energiaressurss']
# ---------------------------------
# ['heakord', 'tulevikuplaan', 'võimuperiood', 'villa', 'hani', 'jäämine', 'karupoeg', 'raviasutus', 'sarv', 'käsilane', 'kits', 'viibimine', 'üksindus', 'omandiõigus', 'rase', 'manustamine']
# ---------------------------------
# ['orbiit', 'tänavapilt', 'väärikus', 'õpetlane', 'analoogia', 'pommitamine', 'galaktika', 'väikeplaneet', 'jälgimis', 'vundament', 'kõver', 'ohje', 'juhtimissüsteem', 'kontrollimine', 'jäljevahemälu']
# ---------------------------------
# ['ümberkirjutamine', 'delta', 'pitsat', 'ilmateade', 'maavõistlus', 'markeering', 'aparaat', 'maaletooja', 'teadaanne', 'liikmekandidaat', 'pressiteade', 'sõidutee', 'liitumiskõnelus', 'sõnaõigus', 'välisvisiit', 'kõnepruuk', 'rahuleping', 'dinosaurus', 'valuutakurss']
# ---------------------------------
# ['mootorratas', 'jõupositsioon', 'tikk', 'paariline', 'kaasmaalane', 'andmeladu', 'vörö', 'ankeet', 'salaviin', 'sündmuskoht', 'konstaabel', 'röövel', 'jünger', 'misjonär', 'tund', 'riigiamet', 'kriminaalvastutus']
# ---------------------------------
# ['määratlemine', 'ääremaa', 'ankeetküsitlus', 'steriliseerimine', 'arendusprojekt', 'dosimeeter', 'hajusarvutus', 'andmeanalüüs', 'pealtvaataja', 'teadusuuring', 'seksuaalkasvatus', 'katel']
# ---------------------------------
# ['naastu', 'tootmine', 'taim', 'parendamine', 'sadam', 'loomaliik', 'talverehv', 'naast', 'variant', 'perefirma', 'tundlikkus', 'kook', 'tootmisvahend', 'käsuvahemälu', 'leibkond', 'kuhi', 'ideoloog']
# ---------------------------------
# ['elutuba', 'võime', 'spermatosoid', 'traavel', 'häirumine', 'väliseestlane', 'maine', 'oma', 'treeninglaager', 'abielunaine', 'imetaja', 'keskklass', 'trots', 'vilumus', 'võrdkuju', 'joonistus', 'majaomanik', 'oskus']
# ---------------------------------
# ['eestvedamine', 'organisatsioonikultuur', 'hiireke', 'lihtsus', 'lipuke', 'eelleping', 'äike', 'imiteerimine', 'kardinal', 'lipp', 'minemine', 'eemaldamine', 'plagu', 'sallivus', 'vesinik', 'parukas', 'mast', 'järgija']
# ---------------------------------
# ['esindatus', 'kaitsepolitsei', 'politseinik', 'kuumus', 'videomäng', 'draama', 'isu', 'ametnik', 'krunt', 'maariba', 'häbi', 'rinnaesine', 'katastroof', 'paber']
# ---------------------------------
# ['telereklaam', 'paar', 'lõvi', 'kõrgrõhkkond', 'teenindus', 'paneel', 'opositsioon', 'kull']
# ---------------------------------
# ['paduvihm', 'olemus', 'tali', 'mõõde', 'arutelu', 'käsitlus']
# ---------------------------------
# ['möödanik', 'üdi', 'isikuomadus', 'pillimees', 'trell', 'tantsimine', 'käsusõna', 'adekvaatsus']
# ---------------------------------
# ['väljaminek', 'elukas', 'kõndimine', 'vaidlus', 'entsefaliit', 'kuulujutt', 'elektrilöök', 'veoauto', 'poolehoidja', 'tinglikkus', 'kergus', 'ülestunnistus', 'aken']
# ---------------------------------
# ['huulepulk', 'teravili', 'kantselei', 'habemetüügas', 'võttegrupp', 'nägu', 'valimiskogu', 'kontor', 'meeskond', 'hõng', 'mängukann', 'esinemine', 'üleskirjutus', 'juurdepääs', 'muld', 'päevitus', 'päikeseketas']
# ---------------------------------
# ['leid', 'selgitus', 'protseduur', 'päevavalge', 'tõukejõud', 'kaevamine', 'ühendus', 'saareke', 'õppija', 'ekspositsioon', 'seisukoht', 'torn']
# ---------------------------------
# ['invasioon', 'vedaja', 'turuliider', 'järk', 'juhtfiguur', 'ettevalmistustöö', 'autoriteet', 'liider', 'sedaan', 'nöör', 'seisukohavõtt', 'soosik', 'tüpoloogia', 'arstiteaduskond', 'tõlkevaste', 'põhijoon']
# ---------------------------------
# ['saanu', 'rahvariie', 'linnakeskus', 'selgitustöö', 'maavaldus', 'kihutustöö', 'hagi', 'lubadus', 'õppekorraldus', 'lähitulevik', 'peaasi', 'võimulolija', 'metroo', 'külvamine', 'ainekava', 'malev']
# ---------------------------------
# ['referendum', 'kirjeldamine', 'järelmõju', 'teadvustamine', 'arutus', 'julgeolekuteenistus', 'vahetuskurss', 'vaade', 'mina', 'eriüksus', 'palvekiri', 'informeerimine']
# ---------------------------------
# ['säile', 'kaotamine', 'protsessortuum', 'korrakaitse', 'pikendamine', 'maandumine', 'kuul', 'elastsus', 'pulk', 'järelemõtlemine', 'umbusaldus', 'enamusvalitsus', 'helkur', 'ühtelangevus']
# ---------------------------------
# ['muundumine', 'feromoon', 'lilleke', 'südametunnistus', 'maailmakaart', 'prostituut', 'sits', 'filter', 'pöörlemine', 'hool', 'murenemine', 'ründeaine', 'pädevus', 'vaimsus']
# ---------------------------------
# ['raamprogramm', 'pidurdamatus', 'intelligentsus', 'tippjuht', 'soo', 'dimensioon', 'koolitus', 'aaloe', 'seotus', 'pall', 'mitmekülgsus', 'juhtimis', 'samastumine', 'kompetentsus', 'salapära', 'rakendus']
# ---------------------------------
# ['näoilme', 'sõnapaar', 'loomaarst', 'maaelu', 'mahajäämus', 'siluett', 'mõttearendus']
# ---------------------------------
# ['stardikapital', 'peapiiskop', 'arutlus', 'madonna', 'purustamine', 'naftamaardla', 'psühholoogia', 'pääsuõigus']
# ---------------------------------
# ['andmeväärtus', 'gradient', 'joondamine', 'täishäälik', 'temperatuurigradient', 'perekonnasuhe', 'keelejuht', 'juurdeehitus', 'formant', 'eristamine', 'navigeerimine', 'vokaal', 'vill', 'rünkpilv', 'rühmatöö', 'tulp']
# ---------------------------------
# ['ostu-müük', 'kausaaltehing', 'kaubandusläbirääkimine', 'leping', 'kinnistamine', 'raamleping', 'olu', 'sõlmimine', 'erakond', 'punkt', 'paremus', 'taimestik']
# ---------------------------------
# ['siire', 'ebanormaalsus', 'seadmestik', 'kamin', 'loetelu', 'näitlejanna', 'palatalisatsioon', 'siirdeala', 'tütarlaps', 'brasiillane', 'kuvand', 'torustik', 'käsujälg', 'konfigureerimine']
# ---------------------------------
# ['läbiviimine', 'põhjaväil', 'parkimismaja', 'rasestumisvastane', 'rahvalaul', 'põhi', 'meetod', 'metodoloogia', 'marketing', 'maantee', 'sündmusrida', 'väärtpaberibörs', 'uurimismeetod']
# ---------------------------------
# ['teemant', 'transistor', 'monarh', 'stiihia', 'aatomituum', 'emis', 'kubu', 'monoloog', 'annetus', 'kooliõpetus', 'kaugõpe', 'lastevanem', 'altar', 'suitsetaja', 'inimgrupp', 'eutanaasia', 'andur', 'põhjustamine']
# ---------------------------------
# ['ravimine', 'sotsiaalhoolekanne', 'mahuti', 'mutism', 'püha', 'poeem', 'raadiokiirgus']
# ---------------------------------
# ['puhkeaeg', 'bussijuht', 'miski', 'küsija', 'müürsepp', 'kannatanu', 'ülekohus', 'paik', 'tarbimine', 'uni', 'kooma', 'aegruum', 'mõistus', 'traktorist', 'vastuolu', 'ansambel', 'suletus', 'magamine']
# ---------------------------------
# ['lohakus', 'ots', 'tegelaskuju', 'kangelanna', 'rajoon', 'lõng', 'kese', 'ühenduslüli', 'nõel', 'lookus', 'tšehh', 'süžee', 'tarkvaraarendus']
# ---------------------------------

# %% [markdown]
# ---

# %% [markdown]
# ### New one

# %%
try:
    cursor.execute("SELECT * FROM pair_counts_10000 WHERE noun IN (SELECT noun FROM pair_counts_10000 GROUP BY noun HAVING COUNT(*) >= 5) AND count >= 3;")
    pairs2 = cursor.fetchall() 
except (Exception, psycopg2.Error) as error:
    con.rollback()
    print("Error while inserting data into the table:", error)

# %%
len(pairs2)
# Out:
# 29112

# %%
adjs2 = list(set([pair[0] for pair in pairs2]))
nouns2 = list(set([pair[1] for pair in pairs2]))

# %%
print(len(adjs2), len(nouns2))
# Out:
# 3152 4373

# %%
df2 = pd.DataFrame(0, index=nouns2, columns=adjs2)
df2.head()
# Out:
#            märgatav  inimesesarnane  energeetiline  moraalne  bürokraatlik  \
# asundus           0               0              0         0             0
# järgnevus         0               0              0         0             0
# sõber             0               0              0         0             0
# hiilgus           0               0              0         0             0
# rahatrahv         0               0              0         0             0
#
#            helesinine  nukleotiidne  kujuline  piinarikas  mehaaniline  ...  \
# asundus             0             0         0           0            0  ...
# järgnevus           0             0         0           0            0  ...
# sõber               0             0         0           0            0  ...
# hiilgus             0             0         0           0            0  ...
# rahatrahv           0             0         0           0            0  ...
#
#            toimiv  põhiline  000kroonine  värvitu  valikuline  paras  \
# asundus         0         0            0        0           0      0
# järgnevus       0         0            0        0           0      0
# sõber           0         0            0        0           0      0
# hiilgus         0         0            0        0           0      0
# rahatrahv       0         0            0        0           0      0
#
#            transformaalne  asümmeetriline  tänulik  sõnalõpuline
# asundus                 0               0        0             0
# järgnevus               0               0        0             0
# sõber                   0               0        0             0
# hiilgus                 0               0        0             0
# rahatrahv               0               0        0             0
#
# [5 rows x 3152 columns]

# %%
for tup in pairs2:
    df2.loc[tup[1], tup[0]] = tup[2]

# %%
import time
from datetime import timedelta, datetime

# %%
start = time.time()
print("Start:", str(timedelta(seconds=start+7200)).split(", ")[1])

lda2 = LatentDirichletAllocation(n_components=1000)
lda2.fit_transform(df2)
# Out:
# Start: 2:24:26.154722
# array([[2.00000000e-04, 2.00000000e-04, 2.00000000e-04, ...,
#         2.00000000e-04, 2.00000000e-04, 2.00000000e-04],
#        [1.25000000e-04, 1.25000000e-04, 1.25000000e-04, ...,
#         1.25000000e-04, 1.25000000e-04, 1.25000000e-04],
#        [2.80112045e-06, 2.80112045e-06, 2.80112045e-06, ...,
#         2.80112045e-06, 2.80112045e-06, 2.80112045e-06],
#        ...,
#        [5.55555556e-05, 5.55555556e-05, 5.55555556e-05, ...,
#         5.55555556e-05, 5.55555556e-05, 5.55555556e-05],
#        [1.66666667e-04, 1.66666667e-04, 1.66666667e-04, ...,
#         1.66666667e-04, 1.66666667e-04, 1.66666667e-04],
#        [6.66666667e-05, 6.66666667e-05, 6.66666667e-05, ...,
#         6.66666667e-05, 6.66666667e-05, 6.66666667e-05]])

# %%
start = time.time()
print("End:", str(timedelta(seconds=start+7200)).split(", ")[1])
# Out:
# End: 2:25:40.340720

# %%
topics_test2 = {}
for i in range(1000):
    topics_test2[i] = []
    
topic_probs_test2 = lda2.transform(df2)
for i, prob in enumerate(topic_probs_test2):
    topics_test2[np.argmax(prob)].append(df2.index[i])

# %%
print([len(topic) for topic in topics_test2.values()])
# Out:
# [103, 1, 2, 9, 4, 3, 2, 3, 6, 7, 2, 1, 3, 3, 3, 3, 0, 1, 0, 5, 5, 3, 5, 2, 10, 0, 1, 1, 2, 3, 1, 0, 4, 3, 6, 0, 0, 4, 2, 0, 3, 2, 5, 5, 36, 0, 0, 0, 1, 2, 0, 4, 0, 3, 1, 0, 4, 1, 38, 6, 18, 2, 7, 4, 4, 4, 5, 3, 6, 1, 4, 3, 1, 2, 1, 0, 1, 3, 0, 1, 4, 1, 0, 85, 4, 6, 3, 1, 4, 21, 8, 0, 0, 2, 2, 2, 0, 3, 2, 0, 0, 4, 3, 0, 0, 6, 1, 5, 1, 5, 8, 3, 2, 1, 4, 1, 0, 7, 0, 4, 4, 2, 3, 1, 0, 4, 1, 0, 8, 40, 0, 0, 0, 2, 2, 0, 12, 0, 3, 1, 3, 2, 12, 3, 2, 0, 2, 3, 5, 3, 2, 6, 2, 2, 4, 2, 2, 7, 7, 0, 0, 2, 1, 0, 0, 0, 1, 2, 2, 1, 19, 1, 0, 9, 6, 1, 12, 0, 3, 1, 1, 0, 0, 0, 7, 4, 2, 2, 0, 3, 0, 0, 0, 1, 1, 1, 3, 28, 1, 4, 2, 1, 3, 2, 0, 0, 2, 5, 1, 1, 1, 4, 3, 2, 6, 1, 0, 4, 0, 14, 1, 2, 32, 19, 1, 6, 0, 14, 0, 164, 0, 81, 1, 0, 0, 1, 4, 3, 4, 1, 0, 3, 11, 0, 3, 3, 0, 29, 2, 0, 8, 2, 1, 3, 1, 0, 2, 5, 4, 6, 8, 0, 4, 1, 0, 1, 0, 0, 0, 4, 2, 0, 3, 1, 4, 0, 4, 5, 1, 0, 1, 9, 2, 0, 6, 11, 7, 3, 8, 1, 14, 3, 9, 5, 0, 2, 1, 5, 0, 4, 0, 0, 1, 5, 2, 4, 2, 3, 1, 1, 1, 0, 1, 1, 1, 9, 3, 3, 0, 9, 0, 11, 5, 0, 3, 3, 3, 0, 1, 2, 3, 2, 1, 0, 11, 0, 1, 0, 3, 3, 1, 2, 3, 2, 3, 1, 5, 2, 1, 0, 6, 0, 4, 0, 45, 0, 3, 0, 0, 4, 0, 0, 0, 0, 1, 2, 2, 0, 2, 0, 0, 3, 2, 0, 1, 1, 2, 3, 1, 0, 2, 0, 0, 8, 2, 0, 0, 2, 0, 5, 3, 4, 8, 18, 1, 6, 2, 6, 2, 5, 0, 4, 1, 4, 5, 1, 4, 1, 2, 3, 0, 9, 1, 0, 0, 0, 9, 5, 0, 4, 1, 0, 3, 3, 3, 1, 4, 0, 0, 8, 6, 5, 0, 0, 1, 0, 4, 8, 2, 6, 5, 1, 1, 0, 6, 4, 4, 2, 3, 5, 4, 1, 2, 0, 0, 0, 1, 4, 4, 1, 4, 0, 3, 0, 3, 3, 9, 1, 6, 11, 6, 2, 14, 11, 1, 4, 0, 2, 47, 1, 2, 16, 5, 0, 0, 2, 0, 4, 14, 1, 2, 0, 1, 0, 0, 3, 3, 0, 0, 2, 1, 2, 2, 5, 8, 3, 0, 3, 0, 7, 0, 2, 2, 0, 6, 3, 2, 3, 5, 2, 0, 7, 1, 0, 1, 2, 3, 0, 1, 6, 1, 1, 40, 0, 1, 1, 1, 8, 0, 0, 0, 8, 0, 11, 59, 2, 0, 1, 9, 1, 0, 1, 3, 1, 7, 12, 0, 0, 5, 5, 1, 1, 10, 2, 1, 4, 2, 2, 2, 1, 15, 7, 2, 3, 8, 1, 3, 0, 19, 0, 3, 2, 2, 0, 4, 31, 0, 1, 1, 6, 1, 37, 2, 6, 2, 2, 4, 2, 1, 0, 0, 3, 5, 6, 3, 1, 2, 3, 1, 12, 0, 5, 0, 1, 0, 6, 0, 5, 2, 0, 0, 1, 0, 28, 2, 4, 9, 6, 5, 1, 6, 0, 0, 5, 3, 1, 2, 0, 1, 3, 0, 1, 0, 12, 1, 4, 3, 3, 0, 9, 1, 1, 1, 4, 1, 4, 0, 1, 6, 3, 3, 2, 13, 0, 1, 8, 14, 4, 8, 27, 5, 1, 9, 3, 3, 1, 1, 3, 0, 0, 1, 2, 0, 0, 0, 3, 3, 1, 1, 3, 1, 0, 0, 2, 1, 5, 3, 0, 5, 2, 0, 2, 5, 2, 0, 4, 0, 2, 1, 7, 0, 1, 2, 7, 3, 1, 0, 10, 3, 4, 7, 3, 3, 0, 0, 3, 21, 0, 3, 10, 3, 1, 5, 10, 0, 4, 6, 0, 0, 2, 0, 47, 1, 2, 4, 1, 38, 2, 2, 4, 0, 10, 0, 6, 1, 1, 3, 0, 2, 1, 10, 3, 1, 0, 4, 10, 2, 5, 0, 4, 6, 0, 8, 9, 4, 11, 0, 3, 0, 3, 1, 0, 16, 2, 2, 3, 7, 1, 4, 1, 3, 0, 4, 2, 3, 10, 2, 1, 5, 0, 1, 3, 37, 8, 15, 1, 0, 0, 1, 11, 1, 11, 3, 2, 4, 5, 2, 0, 0, 2, 0, 3, 1, 0, 9, 0, 2, 5, 11, 0, 1, 3, 0, 4, 1, 3, 68, 0, 5, 4, 20, 0, 3, 1, 0, 0, 7, 9, 3, 8, 4, 0, 3, 3, 0, 6, 4, 1, 0, 4, 1, 0, 5, 2, 9, 1, 2, 5, 10, 1, 0, 4, 0, 2, 2, 6, 29, 0, 3, 0, 1, 2, 2, 36, 1, 1, 2, 0, 0, 2, 0, 2, 0, 4, 1, 2, 3, 0, 1, 12, 3, 1, 0, 0, 5, 8, 2, 5, 10, 4, 0, 234, 18, 1, 1, 1, 5, 2, 2, 1, 0, 1, 3, 2, 2, 0, 0, 3, 19, 3, 15, 6, 0, 2, 6, 2, 1, 11, 26, 0, 0, 3, 1, 3, 2, 17, 3, 1, 2, 4, 1, 2, 6, 0, 3, 4, 0, 3, 1, 22, 1, 35, 0, 0, 5, 20, 2, 1, 0, 2, 35, 0, 6, 10, 1, 3, 2, 0, 0, 0, 0, 1, 3, 0, 1, 4, 0, 0, 0, 2, 3, 3, 7, 1, 3, 16, 0, 0, 0, 4]

# %%
for i in range(1000):
    if len(topics_test2[i]) > 5 and len(topics_test2[i]) < 20:
        print(topics_test2[i])
        print("---------------------------------")
    
    '''print(topics_test2[i])
    print("---------------------------------")'''
# Out:
# ['sekretär', 'toimetaja', 'järjestus', 'teek', 'väljaandja', 'rekonfigureerimine', 'järjestamine', 'konfiguratsioon', 'andmestruktuur']
# ---------------------------------
# ['sisaldus', 'eelis', 'stabiilsus', 'pakt', 'niiskus', 'olulisus']
# ---------------------------------
# ['vabadus', 'riigikord', 'sotsialism', 'õigusriik', 'juhtimisstiil', 'legitiimsus', 'riigikorraldus']
# ---------------------------------
# ['korrasolek', 'dokumentatsioon', 'ülevaatus', 'progress', 'varustatus', 'rike', 'üksikasi', 'arsenal', 'komitee', 'abijõud']
# ---------------------------------
# ['koolilõpetaja', 'suurprojekt', 'linnaeelarve', 'finalist', 'eurolaul', 'autonäitus']
# ---------------------------------
# ['kasutajaliides', 'disain', 'disainimuster', 'liides', 'programmeerimine', 'leht']
# ---------------------------------
# ['rajoon', 'vein', 'täpp', 'terror', 'vaip', 'roos', 'kurat', 'niit', 'tellis', 'kollokatsioon', 'härg', 'moon', 'kilp', 'latern', 'lill', 'kukk', 'tuli', 'väljak']
# ---------------------------------
# ['vanaduspension', 'maksmine', 'eeskiri', 'eeluurimine', 'taotlemine', 'vabanemine', 'saatmine']
# ---------------------------------
# ['kodakondsus', 'tähelepanu', 'hool', 'mõnu', 'tähistamine', 'rõhutamine']
# ---------------------------------
# ['soojus', 'taju', 'loovus', 'uudishimu', 'eksitus', 'nõrkus']
# ---------------------------------
# ['soomlane', 'erakond', 'trump', 'tüli', 'eeskuju', 'teater', 'tänapäev', 'kannatus']
# ---------------------------------
# ['südametunnistus', 'elukeskkond', 'kuld', 'joogivesi', 'räni', 'matemaatika']
# ---------------------------------
# ['katkestamine', 'peatamine', 'talletamine', 'arutamine', 'korraldus', 'kinnisvõlg', 'koormamine', 'pankrotihaldur']
# ---------------------------------
# ['kaelkirjak', 'saamine', 'emane', 'tütar', 'isend', 'õppija', 'isane']
# ---------------------------------
# ['valem', 'teisendus', 'esmapilk', 'juurdepääs', 'arendaja', 'tehe', 'avaldis', 'mikrokontroller']
# ---------------------------------
# ['hiilgus', 'raud', 'pealehakkamine', 'selgus', 'otsustavus', 'rind', 'elujõud', 'tõsidus', 'kõri', 'enesekindlus', 'hoog', 'kindlus']
# ---------------------------------
# ['fraas', 'soeng', 'armulugu', 'elulugu', 'seelik', 'vaheaeg', 'klusiil', 'lõpusibilant', 'sibilant', 'jupp', 'püks', 'repliik']
# ---------------------------------
# ['pealkiri', 'park', 'tugipunkt', 'shampanja', 'pealinn', 'eramu']
# ---------------------------------
# ['asukas', 'teemant', 'ajakirjandus', 'allveelaev', 'ümbrus', 'rand', 'kaart']
# ---------------------------------
# ['lõbu', 'konjak', 'ametiauto', 'viiul', 'pilet', 'superarvuti', 'liide']
# ---------------------------------
# ['omahind', 'kvalifikatsioon', 'haridustase', 'integratsioonitase', 'profiil', 'intressimäär', 'tootmiskulu', 'neurootilisus', 'sööt', 'sündimus', 'puumaja', 'väljatõrjumine', 'iive', 'tootlikkus', 'põõsastik', 'instinkt', 'enesehinnang', 'maksumäär', 'valimisaktiivsus']
# ---------------------------------
# ['statistika', 'kõnepruuk', 'liikmekandidaat', 'maavõistlus', 'teade', 'maaletooja', 'liitumiskõnelus', 'teadaanne', 'kinnitus']
# ---------------------------------
# ['tõrge', 'draama', 'teostus', 'portree', 'lepe', 'ülekoormatus']
# ---------------------------------
# ['sooroll', 'rituaal', 'folkloristika', 'lisaväärtus', 'naiselikkus', 'rollijaotus', 'kaevandamine', 'tööstusharu', 'mehelikkus', 'projektijuhtimine', 'jutustamine', 'tarkvaraarendus']
# ---------------------------------
# ['sähvatus', 'sihik', 'kiirgusväli', 'kiirgus', 'kogemine', 'päikeseenergia', 'kiir']
# ---------------------------------
# ['kasvatus', 'pataljon', 'eelmärge', 'puutumatus', 'kaebus', 'karistamine']
# ---------------------------------
# ['nishsh', 'kõneviis', 'klientuur', 'kellaaeg', 'favoriit', 'diagnoos', 'tõend', 'püstitamine', 'olevik', 'toimumine', 'veendumus', 'suunitlus', 'järjekoht', 'jalgealune']
# ---------------------------------
# ['restoran', 'peakontor', 'väikelinn', 'gaas', 'kõrts', 'lennuväli', 'baar', 'staap', 'angaar', 'peakorter', 'küla', 'ladu', 'juhtimiskeskus', 'lasteaed', 'hoov', 'bensiinijaam', 'tankla', 'suvila', 'garaazh']
# ---------------------------------
# ['hulk', 'tegelaskond', 'vahemik', 'mäss', 'organisatsioon', 'juga']
# ---------------------------------
# ['identifitseerimine', 'vahendus', 'pangandus', 'folkloor', 'maksesüsteem', 'esituskuju', 'pangateenus', 'segaja', 'post', 'õppematerjal', 'kanal', 'press', 'keelevara', 'notar']
# ---------------------------------
# ['taimkate', 'aineringlus', 'märgala', 'karjamaa', 'bioom', 'veeringlus', 'veekogu', 'opositsioon', 'foon', 'taimestik', 'ökosüsteem']
# ---------------------------------
# ['keelekasutus', 'leib', 'kodutöö', 'pisiasi', 'tarbeese', 'trenn', 'olme', 'harjumus']
# ---------------------------------
# ['katus', 'arhitektuur', 'protsessor', 'andmesõna', 'operatsioonisüsteem', 'implikatuur']
# ---------------------------------
# ['poliitik', 'finantsasutus', 'teadusajakiri', 'IT-firma', 'tööstusriik', 'suurriik', 'etendus', 'tehnoloogiafirma']
# ---------------------------------
# ['kiirustamine', 'kehakaal', 'joomine', 'luksus', 'kilo', 'laenamine', 'kilogramm', 'optimism', 'embrüo']
# ---------------------------------
# ['õpetus', 'demokraat', 'sümboolika', 'ühing', 'teism', 'eetika']
# ---------------------------------
# ['käekell', 'võitja', 'maailmameistrivõistlus', 'omandamine', 'viljakus', 'kahjum', 'lagi', 'ostja', 'kasum', 'omandaja', 'liituja']
# ---------------------------------
# ['kunstnik', 'laulja', 'ajakirjanik', 'kirjanik', 'näitleja', 'literaat', 'luuletaja']
# ---------------------------------
# ['provints', 'jätkumine', 'treener', 'asuala', 'hinnatase', 'valitsuskoalitsioon', 'regionaalminister', 'kaitseministeerium']
# ---------------------------------
# ['naer', 'auditoorium', 'rinne', 'suu', 'kandepind', 'sein', 'spekter', 'publik', 'kõlapind', 'haare', 'silmaring', 'kaar', 'naeratus', 'vaateväli']
# ---------------------------------
# ['usaldus', 'abistamine', 'süüdistus', 'usaldamatus', 'tunnustamine', 'mõjutamine', 'sõltuvusseos', 'süüdistamine', 'lugupidamine']
# ---------------------------------
# ['kest', 'värav', 'põhjendus', 'pihk', 'tasku', 'pudel', 'kõht', 'list', 'kott']
# ---------------------------------
# ['ratas', 'võlg', 'parvlaev', 'elamine', 'auto', 'buss', 'müüja', 'elamu', 'laev']
# ---------------------------------
# ['legend', 'hani', 'ungarlane', 'klassik', 'loode', 'doonor', 'kõnekeel', 'arvukus', 'surnu', 'kaasmaalane', 'mitte-eestlane']
# ---------------------------------
# ['tunnetus', 'vale', 'pea', 'säng', 'ava', 'tähelepanek', 'mõõt', 'märkimine', 'kohtunik', 'klahv', 'hõlm']
# ---------------------------------
# ['liikleja', 'rool', 'pereisa', 'autorool', 'autojuht', 'staadion']
# ---------------------------------
# ['tegutsemisstrateegia', 'majanduspoliitika', 'tarkvarasüsteem', 'mõtlemis', 'mobiil', 'mobiiltelefon', 'majandussüsteem', 'telefon']
# ---------------------------------
# ['ausus', 'kaalutlus', 'dilemma', 'nihilism', 'laine', 'eristus', 'ideaal', 'imperatiiv']
# ---------------------------------
# ['paar', 'korralagedus', 'mentaliteet', 'kolmikliit', 'mõttelaad', 'asjaõigus', 'konservatiiv', 'kuuluvus', 'saareke', 'kinnisasi', 'sotsiaaldemokraat', 'mängija', 'hunt', 'looja', 'saar', 'vanainimene', 'aatom', 'entusiast']
# ---------------------------------
# ['ajaleht', 'jumal', 'asesõna', 'kampaania', 'päevaleht', 'võimuvõitlus']
# ---------------------------------
# ['maastur', 'server', 'gammakiirgus', 'mootor', 'plahvatus', 'häärber']
# ---------------------------------
# ['abort', 'kirjandusteadus', 'juubilar', 'luup', 'keskkoolilõpetaja', 'võimumees', 'linnavõim', 'lõpetaja', 'kroonika']
# ---------------------------------
# ['uks', 'ümbrik', 'emissioon', 'vangla', 'meistrivõistlus', 'ring', 'finaal', 'alamruum', 'kera']
# ---------------------------------
# ['liigendus', 'formatiiv', 'andmetöötlus', 'tähis', 'ühestaja', 'sisend', 'usaldusväärsus', 'süntees']
# ---------------------------------
# ['tegija', 'kohv', 'hoidmine', 'õlu', 'alkohol', 'ühendus']
# ---------------------------------
# ['vaesus', 'valdaja', 'välisinvesteering', 'näit', 'ülemus', 'järeltulija', 'omandusvaldaja', 'valdus']
# ---------------------------------
# ['elanik', 'muulane', 'kooseksisteerimine', 'krediidiasutus', 'rööpsus', 'venelane']
# ---------------------------------
# ['katsetus', 'näht', 'keskhaigla', 'avaldus', 'metall', 'pilt']
# ---------------------------------
# ['ribalaius', 'olu', 'tänav', 'huviline', 'gümnaasium', 'spetsialiseerumine', 'riba', 'maariba', 'pilu']
# ---------------------------------
# ['laul', 'järk', 'kodusõda', 'kirves', 'sett', 'süstal']
# ---------------------------------
# ['ülemnõukogu', 'välisminister', 'siseminister', 'rektor', 'direktor', 'peadirektor', 'kantsler', 'majandusminister', 'suursaadik', 'ülem', 'valitseja']
# ---------------------------------
# ['psühhoos', 'lahing', 'unehäire', 'enurees', 'sõnasõda', 'intoksikatsioon']
# ---------------------------------
# ['kaubanduspartner', 'uurimisobjekt', 'uurimisvaldkond', 'sissetulekuallikas', 'melu', 'toetaja', 'kahtlusalune', 'huviobjekt', 'kunstinäitus', 'takistus', 'tuluallikas', 'võlu', 'tegevusala', 'eestkõneleja']
# ---------------------------------
# ['lõpetamine', 'suurfirma', 'äritegevus', 'keskklass', 'lõppemine', 'ärimees', 'teadustöö', 'toimimine', 'sooritamine', 'elukutse', 'elluviimine']
# ---------------------------------
# ['kullaauk', 'fänn', 'haruldus', 'programmeerija', 'staar', 'paradiis', 'piin', 'professionaal', 'sõprus', 'läbimurre', 'maiuspala', 'nuhtlus', 'katastroof', 'planeedisüsteem', 'buum', 'pale']
# ---------------------------------
# ['interaktsioon', 'vestlus', 'ühendamine', 'suhtlus', 'heitlus', 'kõnelus', 'infovahetus', 'korrelatsioon', 'võrdlus', 'kommunikatsioon', 'kemplemine', 'proportsioon', 'jutuajamine', 'põrge']
# ---------------------------------
# ['tants', 'ebaõiglus', 'mälestusmärk', 'romaan', 'ilukirjandus', 'paratamatus', 'ks-ühend', 'kultuurilooline']
# ---------------------------------
# ['verejooks', 'lõhestatus', 'mina', 'sund', 'reserv', 'ühtsus', 'riskijuhtimine']
# ---------------------------------
# ['liider', 'peatoimetaja', 'elukäik', 'maksimum', 'kurss', 'kultuuritraditsioon']
# ---------------------------------
# ['mäenõlv', 'vähenemine', 'pööre', 'vähendamine', 'halvenemine', 'langus', 'nõlv']
# ---------------------------------
# ['reguleerimine', 'regulatsioon', 'alus', 'võlasuhe', 'järjepidevus', 'võõrvaldaja']
# ---------------------------------
# ['testija', 'ekspert', 'registrikogum', 'erakõrgkool', 'telekanal', 'jälgija', 'ametiühing', 'televisioon']
# ---------------------------------
# ['tööhõive', 'ioon', 'iseloom', 'imago', 'tulem', 'laeng', 'vastukaja', 'anomaalia']
# ---------------------------------
# ['vastamine', 'lähtekoht', 'õppelaen', 'pangalaen', 'pensioniseadus', 'rakk', 'arve', 'vereproov', 'jätmine', 'prognoos', 'proov']
# ---------------------------------
# ['automaat', 'padrun', 'muutuja', 'loend', 'kaliiber', 'valmimine', 'rahulepe', 'jõudmine', 'otsustamine']
# ---------------------------------
# ['kiirtee', 'deklaratsioon', 'domineerimine', 'toide', 'kinkimine', 'tahteavaldus', 'kinnistusamet']
# ---------------------------------
# ['osalus', 'sõnaraamat', 'soomus', 'klapp', 'surmamine', 'eutanaasia', 'osalemine', 'kasvuhoonegaas', 'arusaamine', 'suguelu', 'eluhoiak', 'osaleja']
# ---------------------------------
# ['riigipea', 'peasekretär', 'tariif', 'keeleseadus', 'funktsionaalsus', 'eelkäija', 'parlament', 'maksusüsteem', 'linnavalitsus', 'peatreener']
# ---------------------------------
# ['õigusteadus', 'meditsiin', 'kõrgharidus', 'väljaanne', 'sõjaajalugu', 'järelkasv', 'inventar', 'maailmapilt', 'kraad', 'kommunism', 'kirjanduslugu', 'selts', 'liikuvus', 'uurimistöö', 'publikatsioon']
# ---------------------------------
# ['medal', 'õnnistus', 'meeskonnaliige', 'teljestik', 'pretendent', 'lennuk', 'pill']
# ---------------------------------
# ['pärand', 'uuestisünd', 'alaareng', 'väsimus', 'taastumine', 'puue', 'võimekus', 'kapatsiteet']
# ---------------------------------
# ['saavutamine', 'abinõu', 'luulumõte', 'turvameede', 'määratlemine', 'riistvara', 'tunnistus', 'abivahend', 'toiming', 'oskusteave', 'kindlaksmääramine', 'parandus', 'andmeturve', 'määrang', 'mikroelement', 'tüvevariant', 'kogumine', 'kooskõlastamine', 'tööriist']
# ---------------------------------
# ['opereerimine', 'täisarv', 'aparatuur', 'operand', 'freim', 'programmeerimiskeel']
# ---------------------------------
# ['sotsiaaltöö', 'erialakultuur', 'juhtimisteooria', 'kommunikatsioonitehnoloogia', 'sõjavägi', 'vabadussõda']
# ---------------------------------
# ['koostööleping', 'maantee', 'vägikaikavedu', 'kaugus', 'tühimik', 'distants']
# ---------------------------------
# ['peavalu', 'möödalaskmine', 'tegelemine', 'töömees', 'majandusraskus', 'mure', 'proovikivi', 'hoiatus', 'tervisehäire', 'tagasilöök', 'kahtlus', 'jünger']
# ---------------------------------
# ['konsensus', 'murrang', 'transport', 'alamsüsteem', 'eelarvamus', 'moraalinorm']
# ---------------------------------
# ['hea', 'keeleoskus', 'kohtlemine', 'enesetunne', 'kolesterool', 'kättesaadavus', 'nähtavus', 'unenägu', 'uudis']
# ---------------------------------
# ['lõhn', 'haldusreform', 'kaotamine', 'vastuväide', 'külg', 'vastastikmõju']
# ---------------------------------
# ['viha', 'ahv', 'jäämine', 'rauk', 'udu', 'sügisõhtu']
# ---------------------------------
# ['talu', 'kell', 'hotell', 'vägi', 'järv', 'saatkond', 'tehas', 'elumaja', 'mägi', 'vallutamine', 'kauplus', 'pood']
# ---------------------------------
# ['joogi', 'jook', 'infoühiskond', 'tank', 'mikroprotsessorlülitus', 'muuseum', 'mikroprotsessorsüsteem', 'kõrgjõudlus', 'kunst']
# ---------------------------------
# ['eeltöö', 'vaatlemine', 'renoveerimine', 'kaalumine', 'ülevaade', 'käik']
# ---------------------------------
# ['kujutus', 'valmisolek', 'jälgimine', 'deformatsioon', 'enesetäiendamine', 'reisimine', 'ajakohastamine', 'muutumine', 'hooldus', 'kangelastegu', 'tõmbamine', 'uuendamine', 'kordaja']
# ---------------------------------
# ['täiskasvanuiga', 'astroloogia', 'lapsepõli', 'noorus', 'lapseiga', 'ilming', 'staadium', 'noorukiiga']
# ---------------------------------
# ['katsumus', 'ratsavägi', 'põletushaav', 'joove', 'majandusseis', 'haigla', 'väikelaps', 'tüsistus', 'trauma', 'avarii', 'majandusolu', 'vigastus', 'koorem', 'liiklusõnnetus']
# ---------------------------------
# ['asula', 'ülekaal', 'saak', 'iroonia', 'aktsent', 'muie', 'vaev', 'eine']
# ---------------------------------
# ['lämmastik', 'kogumik', 'heroiin', 'sari', 'zhürii', 'välistuum', 'olek', 'väävelhape', 'magma']
# ---------------------------------
# ['kallim', 'kabinet', 'maavanem', 'koduklubi', 'liige', 'kodumaa', 'esimees']
# ---------------------------------
# ['kokkuvarisemine', 'valitsuspartei', 'keskkomitee', 'diktatuur', 'ideoloogia', 'rezhiim', 'režiim']
# ---------------------------------
# ['vastupidavus', 'inimkapital', 'hävitamine', 'turve', 'vägivald', 'kurnatus', 'vaevus', 'ettevõtja', 'kohalolek', 'koormus']
# ---------------------------------
# ['lumi', 'rahakott', 'ketas', 'klaas', 'köide', 'kingitus', 'prill']
# ---------------------------------
# ['inimareng', 'veri', 'võrdõiguslikkus', 'proua', 'abielupaar', 'jagunemine', 'diskrimineerimine', 'raport', 'iseärasus', 'säästumäär']
# ---------------------------------
# ['vanatüdruk', 'pruut', 'kaupmees', 'vaene', 'sõnum', 'klubi', 'järelepärimine', 'mäluruum', 'kutse', 'kiri']
# ---------------------------------
# ['ühend', 'ründeaine', 'muundumine', 'koostis', 'regressioon', 'murenemine']
# ---------------------------------
# ['sügis', 'aprill', 'laupäev', 'juuli', 'pankrot', 'täis', 'september', 'teisipäev', 'reede', 'kolmapäev']
# ---------------------------------
# ['raamatukogu', 'sugu', 'internetiühendus', 'arhiiv', 'toimetus', 'majapidamine']
# ---------------------------------
# ['Interneti-ühendus', 'vahetumine', 'andmevahetus', 'rada', 'kahanemine', 'reageerimine', 'vasturünnak', 'tempo', 'vaheldumine', 'elutempo']
# ---------------------------------
# ['eellugu', 'elektrivool', 'soojenemine', 'tsüklon', 'kapitalism', 'vihmamets', 'vöönd', 'kliimamuutus', 'orkaan', 'koordinaadistik']
# ---------------------------------
# ['äraelamine', 'valk', 'gravitatsiooniväli', 'vahekord', 'talitlus', 'raskuskiirendus']
# ---------------------------------
# ['relativism', 'repertuaar', 'tätoveering', 'erisus', 'praktika', 'määrsõna', 'tunnetamine', 'paljusus']
# ---------------------------------
# ['mõrvar', 'loovutamine', 'insener', 'monarh', 'city', 'põli', 'kuningas', 'abikaasa', 'proff']
# ---------------------------------
# ['loss', 'igavik', 'lähedane', 'kino', 'leegion', 'mõistus', 'hammas', 'personal', 'poolaeg', 'seeria', 'rida']
# ---------------------------------
# ['kaas', 'hooldamine', 'eellane', 'nimetaja', 'laud', 'õpiobjekt', 'välispoliitika', 'e-õpe', 'haldamine', 'söömaaeg', 'veebileht', 'jooming', 'haud', 'jõupingutus', 'portaal', 'rajatis']
# ---------------------------------
# ['mürsk', 'potentsiaal', 'kivi', 'panus', 'andmehulk', 'populaarsus', 'menu']
# ---------------------------------
# ['bensiinimootor', 'elektronpost', 'telefonikõne', 'koolilaps', 'pandimüük', 'lauaarvuti', 'televiisor', 'turbodiisel', 'galaktika', 'mõjutus']
# ---------------------------------
# ['jõudluspiirang', 'RISC-protsessor', 'polaarring', 'ballett', 'RISC-arhitektuur', 'tragöödia', 'kaanon', 'looduskaitse']
# ---------------------------------
# ['lehekülg', 'lisa', 'katse', 'aastasada', 'maailmasõda', 'ohver', 'trend', 'veer', 'avalikkus', 'singel', 'kohus', 'lint', 'trükk', 'nimetus', 'börs']
# ---------------------------------
# ['abielumees', 'ringlus', 'veetmine', 'radikaal', 'sõnaühend', 'võnkumine', 'härra', 'sisustamine', 'ligipääs', 'langemine', 'elektron']
# ---------------------------------
# ['rahatrahv', 'altkäemaks', 'maatükk', 'maa-ala', 'klaster', 'preemia', 'ruutmeetrihind', 'nimiväärtus', 'kautsjon', 'trahv', 'aastakäive']
# ---------------------------------
# ['töötu', 'rent', 'autentsus', 'rendileping', 'säilitamine', 'krediit', 'perspektiiv', 'rahapaigutus', 'töötus']
# ---------------------------------
# ['geomeetria', 'asutamine', 'piiblitõlge', 'kirikukirjandus', 'õpitarkvara', 'väljend', 'allilm', 'vaste', 'tõlge', 'piibel', 'terminoloogia']
# ---------------------------------
# ['relvaäri', 'migratsioon', 'uimasti', 'ravimine', 'mutism', 'häälik', 'immigrant']
# ---------------------------------
# ['identsus', 'energiaallikas', 'selgitus', 'investeerimisvõimalus', 'lähenemine', 'psühholoogia', 'leksika', 'iva', 'seletus']
# ---------------------------------
# ['saastumine', 'lagunemine', 'jäätmehoidla', 'süsinik', 'isotoop', 'saast', 'preparaat', 'saaste']
# ---------------------------------
# ['arendamine', 'tunnusjoon', 'mõiste', 'faas', 'märksõna', 'tarbija']
# ---------------------------------
# ['õigustehing', 'problemaatika', 'ostueesõigus', 'muutmine', 'õigusmuudatus', 'lahutamine', 'käigukast', 'morfoloogia', 'transformeerimine']
# ---------------------------------
# ['märk', 'visioon', 'siht', 'vähemus', 'taevas', 'ettekujutus', 'mandaat', 'IS-strateegia', 'piirjoon', 'vihje']
# ---------------------------------
# ['kolimine', 'müüt', 'lavastus', 'pindala', 'armastus', 'jagu']
# ---------------------------------
# ['sisu', 'tööandja', 'ettepanek', 'persoon', 'tegevuskava', 'veovahend', 'võõrkeel', 'tüvi', 'koostamine', 'õigusnorm', 'litsents', 'vald']
# ---------------------------------
# ['kuritarvitamine', 'erutus', 'rünne', 'orientatsioon', 'küpsemine', 'ahistamine', 'ärakasutamine', 'rahuldus']
# ---------------------------------
# ['vastutus', 'kära', 'lemmik', 'kaal', 'kiindumus', 'pingutus', 'huvi', 'rõõm', 'teene', 'rõhk']
# ---------------------------------
# ['pulber', 'lina', 'kinnas', 'pressiesindaja', 'ratsu', 'kleit', 'sokk', 'rass', 'sinikrae', 'kepp', 'laik', 'särk', 'paberileht', 'triip', 'viin', 'laid', 'hiir', 'kääbus']
# ---------------------------------
# ['indeks', 'rääkimine', 'test', 'taotlus', 'blankett', 'erilisus', 'kohaldamine', 'palve', 'koolitus', 'võrrand', 'protokoll', 'lahter', 'privaatvõti', 'instants', 'näitaja', 'keeld', 'ametiasutus', 'luba', 'keskkonnaministeerium']
# ---------------------------------
# ['pärastlõuna', 'käsiraamat', 'naispolitseiametnik', 'direktiiv', 'esitamine', 'protsent', 'kirjeldamine', 'kirjatöö', 'autor', 'praegu-hetk', 'ettekanne', 'stseen', 'juuni', 'kirjutis', 'kirjatükk']
# ---------------------------------
# ['astronoom', 'residents', 'tõsi', 'pulm', 'kõrgus', 'kolleegium']
# ---------------------------------
# ['ese', 'autoriõigus', 'objekt', 'taldrik', 'riigiasutus', 'robot']
# ---------------------------------
# ['algebra', 'põhimäärus', 'hankimine', 'doonorlus', 'komisjon', 'õigusrikkumine', 'relv', 'omamine', 'muutkond', 'mõjutusvahend', 'jälitustegevus']
# ---------------------------------
# ['mantel', 'meri', 'komöödia', 'masendus', 'kassa', 'lind', 'huumor', 'kass', 'nimekiri', 'maagia', 'valge', 'pesu', 'lammas', 'stsenaarium', 'kast', 'kurg', 'hobune']
# ---------------------------------
# ['elupaik', 'osatäitja', 'õppeaine', 'töökeskkond', 'leidmine', 'kujundamine']
# ---------------------------------
# ['põhitoonikontuur', 'tiraazh', 'segatüüp', 'laen', 'stuupor', 'episood']
# ---------------------------------
# ['aktsioon', 'kokkupõrge', 'ähvardus', 'otstarve', 'kateeder', 'agressioon', 'vaatleja', 'allianss', 'doktriin', 'riigipööre']
# ---------------------------------
# ['määrus', 'põhiseadus', 'seadustik', 'õigusakt', 'seadmine', 'seadusandlus', 'liikluseeskiri']
# ---------------------------------
# ['delegeerimine', 'footon', 'sotsiaalpedagoog', 'kompetents', 'hektar', 'juurdlus', 'müümine', 'kujutis', 'ammendumine', 'määratlus', 'diplomaat', 'veeaur', 'seaduseelnõu', 'galerii', 'silt', 'tshehh']
# ---------------------------------

# %%
for i in range(100):
    if len(topics_test2[i]) < 10:
        print(topics_test2[i])
        print("---------------------------------")
# Out:
# ['äraelamine', 'valimistulemus', 'olemus', 'leib', 'oht', 'praktika', 'tarbeese', 'elu', 'oks']
# ---------------------------------
# ['soojus', 'ülekanne', 'fakt', 'laul', 'kütus', 'julgeolekuteenistus', 'olemine', 'näide', 'tulevik']
# ---------------------------------
# ['spetsialist', 'kartul', 'abort', 'õigusakt', 'tugipunkt', 'pensionär', 'elusündmus', 'seadusandlus']
# ---------------------------------
# ['periood', 'perekond', 'tee', 'töö', 'keerukus', 'järjekindlus']
# ---------------------------------
# ['kaamera', 'info', 'keskkond', 'problemaatika', 'probleem', 'muutmine', 'andmed', 'kiri']
# ---------------------------------
# ['võim', 'liider', 'riigivõim', 'süsteem', 'teenus', 'ühiskond', 'leiutis', 'konveier']
# ---------------------------------
# ['aeg', 'personal', 'politseinik', 'õppevorm']
# ---------------------------------
# ['igavik', 'soojenemine', 'mõistus', 'pere', 'varandus', 'diskrimineerimine', 'rida', 'genitiiv', 'iseärasus']
# ---------------------------------
# ['pähkel', 'dokument', 'tipp', 'sõna', 'lipp', 'enamik', 'hääl', 'enamus', 'afrikaat']
# ---------------------------------
# ['mentaliteet', 'kolmikliit', 'tegutsemine', 'varjupaik', 'kodanik', 'transport', 'alamsüsteem', 'ringkond', 'kultuur']
# ---------------------------------
# ['ilm', 'järeldus', 'kuju', 'korruptsioon', 'metall']
# ---------------------------------
# ['aerosool', 'tuhk', 'isikuandmed', 'klaas', 'minevik', 'sündmus', 'õpetamine', 'küsimus']
# ---------------------------------
# ['kinnistusraamat', 'keemia', 'pea', 'käsi', 'sissekanne', 'aim', 'mees', 'kasutamine']
# ---------------------------------
